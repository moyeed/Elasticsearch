# %% [markdown]
# <a href="https://colab.research.google.com/github/moyeed/Elasticsearch/blob/main/elastic_search_spotlight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# #CSCI-642: Information Storage and Retrival
# ##Spotlight: ElasticSearch
# ##Authors:
#
# > **1) Mohammed Abdul Moyeed(Z1912165)**
#
# > **2) Omer Bin Ali Bajubair(Z1905006)**
#
# ---

# %% [markdown]
# # Introduction
# * Elastic  Search is a powerful text retrival and analysis tool.
# * While most of the databases are enough for storing structured data, Elastic search not only helps in storing structured, unstructed or any type of huge data efficiently but also provides scalable search, various filtering, sharding and visualization abilities in real time.
# * It also maintains powerful API, that allows to acces elastic search from any device and language.
# * ElasticSearch is an interface to Lucene(an open source java library for text search) designed for BIGDATA from ground to up, including all the features of Lucene out of box.
# * Elastic Search can be accessed in diferent ways,
#
# >> 1) Download to local machine and run it on local server when ever needed.
#
# >> 2) Create an Insatnce on cloud services like AWS, AZURE, etc. and access it on their dashboard.
#
# >> 3) Create a cloud server on elastic search website itself(we have followed this for simplicity and easy access)

# %% [markdown]
# # Getting Started : Connecting to our ElasticSearch Instance.

# %% [markdown]
# ## Install elasticSearch python library.

# %%
# %run -m pip install elasticsearch
# Out:
# Collecting elasticsearch
#   Downloading elasticsearch-7.15.1-py2.py3-none-any.whl (378 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch) (2021.5.30)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch) (1.24.3)
# Installing collected packages: elasticsearch
# Successfully installed elasticsearch-7.15.1

# %% [markdown]
# ## Connection to Elastic Search Insatnce: There are many ways depedning on how you are using the elastic search, below mentioned are few of them.
#
# > 1) If you have elastic search downloaded to local machine and it is running, you can use "connection_with_local_server method after running the elastic insatnce on oyur machine and providng correct port.
#
# > 2) You can connect using the API key or cloud_id if the server is instatiated on cloud using any of the two methods, "connection_with_API_key" or "connection_with_cloud_id"

# %%
from elasticsearch import Elasticsearch,helpers

def connection_with_local_server(port : str):
  es = Elasticsearch(
      {'host':'localhost',port:port})
  es.ping()

  return es

def connection_with_API_key(list_of_nodes,API_key : str):
  es = Elasticsearch(
    list_of_nodes,    #['node-1', 'node-2', 'node-3']
    api_key=('id', API_key),
)
  es.ping()

  return es

def connection_with_cloud_id(cloud_id,password):
  es = Elasticsearch(
      cloud_id = cloud_id,
      http_auth=("elastic", password),
  )
  es.ping()

  return es

es = connection_with_cloud_id("ISR-spotlight:ZWFzdHVzMi5henVyZS5lbGFzdGljLWNsb3VkLmNvbTo5MjQzJDc0MzJjNTg4M2I1MjQ2ZGViYzllOWJmNTE0YzFlNTUyJDM4NTJjMTIyNTg3YzQ5NWViZjQxMDQ0ZGExZTNkNGFi","G33hwear6NKHA79sa3EwNwHK")
# Out:
# GET https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/ [status:200 request:0.512s]
# HEAD https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/ [status:200 request:0.092s]

# %% [markdown]
# # Working with Indices (Tables)
#
# > * Generally a Database is called Index in elastic search till version 7 but in further releases the Index is a table not database.
#
#
# > * All the methods we are calling using the es insatnce will result in an API call either GET, PUT, POST or DELETE based on each operation and their states can be seen in the output of each execution.

# %% [markdown]
# ## Creating a new Index
#
# > * creating a new database or index uses PUT request to our server.

# %%
def create_index(index_name):
  response = es.indices.create(index = index_name,ignore = 400)
  if(response.get("acknowledged",False)):
    print("index created")

create_index("data")
# Out:
# PUT https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/data [status:200 request:0.286s]
# index created

# %% [markdown]
# ## Getting all currently available indices or Tables
#
# > * This uses a GET request to fetch all indices.

# %%
def list_all_indices(index_name):
  indices_list = es.indices.get_alias(index = index_name)
  for each_index in indices_list:
    if(each_index.startswith(".") or each_index.startswith("apm")):
      continue
    print(each_index)

list_all_indices("*")
# Out:
# GET https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/*/_alias [status:200 request:0.099s]
# student
# data
# facebook_outage_tweets
# kibana_sample_data_flights
# /usr/local/lib/python3.7/dist-packages/elasticsearch/connection/base.py:209: ElasticsearchWarning: this request accesses system indices: [.kibana_task_manager_7.15.1_001, .kibana_security_session_1, .tasks, .fleet-servers-7, .apm-agent-configuration, .fleet-policies-leader-7, .kibana_7.15.1_001, .fleet-enrollment-api-keys-7, .fleet-agents-7, .fleet-policies-7, .apm-custom-link, .security-7, .async-search, .security-tokens-7], but in a future major version, direct access to system indices will be prevented by default
#   warnings.warn(message, category=ElasticsearchWarning)
# /usr/local/lib/python3.7/dist-packages/elasticsearch/connection/base.py:209: ElasticsearchWarning: this request accesses aliases with names reserved for system indices: [.fleet-policies-leader, .kibana_7.15.1, .kibana_task_manager, .fleet-agents, .fleet-enrollment-api-keys, .kibana_task_manager_7.15.1, .security-tokens, .fleet-servers, .security, .kibana, .fleet-policies], but in a future major version, direct access to system indices and their aliases will not be allowed
#   warnings.warn(message, category=ElasticsearchWarning)

# %% [markdown]
# ## Deleting an index or table
#
# > * This uses a DELETE request to detlete required index.

# %%
def delete_index(index_name):
  response = es.indices.delete(index = index_name)
  if(response.get("acknowledged",False)):
    print("index deleted")

delete_index("data")
# Out:
# DELETE https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/data [status:200 request:0.204s]
# index deleted

# %% [markdown]
# # Deploy/Access data in Elasticsearch indices
#
# > * We can use JSON to add structured data in the index.
#
#
# > * Each index or table is given an unique id to it.
#
# > * The acknowledgement message shows all the attributes discussed above.

# %%
delete_index("student")
create_index("student")
# Out:
# DELETE https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/student [status:200 request:0.207s]
# index deleted
# PUT https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/student [status:200 request:0.268s]
# index created

# %%
#create a JSON data for students table
student1 = {
    "name":"Moyeed",
    "Z-id":"Z-1912165",
    "level": "Graduate",
    "Location":"Dekalb"
}
student2 = {
    "name":"Omer",
    "Z-id":"Z-1905006",
    "level": "Graduate",
    "Location":"Dekalb"
}

#create a studnet table and insert this data
es.index(index = "student", document = {"s1":student1,"s2":student2})
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/student/_doc [status:201 request:0.181s]
# {'_id': 'qIJhmXwBUCa3jWZUdwQw',
#  '_index': 'student',
#  '_primary_term': 1,
#  '_seq_no': 0,
#  '_shards': {'failed': 0, 'successful': 2, 'total': 2},
#  '_type': '_doc',
#  '_version': 1,
#  'result': 'created'}

# %% [markdown]
# ## Import data from pandas dataframe to elasticsearch Index.

# %% [markdown]
# ### downlad the dataset and extract it.

# %%
import zipfile
import os
from urllib.request import urlretrieve

import pandas as pd

file_to_download = ("tweets","https://github.com/moyeed/Elasticsearch/raw/main/tweets.zip")
dataset_fileName = ("Facebook_outage_Tweet_data_4th_October.csv","/content/Facebook_outage_Tweet_data_4th_October.csv")
if not os.path.exists(file_to_download[0]):
  urlretrieve(file_to_download[1], file_to_download[0])
  print("zip file downloaded")

if not os.path.exists(dataset_fileName[0]):
  # !unzip /content/tweets
  print("Facebook_outage_Tweet_data_4th_October.csv, extracted from zip file")
# Out:
# zip file downloaded
# Archive:  /content/tweets
#   inflating: Facebook_outage_Tweet_data_4th_October.csv
# Facebook_outage_Tweet_data_4th_October.csv, extracted from zip file

# %% [markdown]
# ### Read the data into a pandas datframe and replace Null values with -1.
# > * Pandas dataframe does not have any problem with holding null values, but elasticsearch does not support indexing null values for efficiency purposes.

# %%
fb_outage_tweets_df = pd.read_csv(dataset_fileName[1], error_bad_lines=False)
fb_outage_tweets_df = fb_outage_tweets_df.fillna("-1")
fb_outage_tweets_df.drop(columns = ["thumbnail"]) 
# print(df.isnull().sum())
fb_outage_tweets_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                     id      conversation_id  ... trans_src trans_dest
# 0  1445144194033590276  1445144194033590276  ...        -1         -1
# 1  1445144194025246720  1445144194025246720  ...        -1         -1
# 2  1445144193849073670  1445141972323344384  ...        -1         -1
# 3  1445144193819574285  1445144193819574285  ...        -1         -1
# 4  1445144193714774025  1445144193714774025  ...        -1         -1
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Create a generator object that can be sent for uploadig dataset from pandas dataframe to our index.
# > * we can import the dataset through kibana but the file should be less than 100mb, if the saize is greater, we can use something called bulk upload programatiically.
#
# > * we have to create a generator to upload huge datasets to elastic search programatically.

# %%
def generator_for_bulk_upload(dataframe):
  columns = list(dataframe.columns)
  # print(type(df))
  # print(columns)
  for index, each_record in dataframe.iterrows():
    temp_source = {}
    # print(each_record[0])
    # for index,col in enumerate(columns):
    for col in columns:
      temp_source[col] = each_record[col]
    yield {
        '_index':'facebook_outage_tweets',
        '_id':each_record.id,
        '_source':temp_source
    }
# gen = generator_for_bulk_upload(fb_outage_tweets_df)

# %% [markdown]
# ### create index to upload, if not already present.

# %%
# next(gen)
if es.indices.exists(index="facebook_outage_tweets"):
  print("index already exists")
  pass
else:
  create_index("facebook_outage_tweets")
# Out:
# HEAD https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets [status:200 request:0.098s]
# index already exists

# %% [markdown]
# ### upload the data in dataframe to elaticsearch index using _bulk API

# %%
helpers.bulk(es,generator_for_bulk_upload(fb_outage_tweets_df))
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.544s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.355s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.388s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.387s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.366s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.377s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.368s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.339s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.363s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.384s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.376s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.312s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.358s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.314s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.359s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.373s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.363s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.278s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.345s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.410s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.278s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.349s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.354s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.365s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.278s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.340s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.365s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.260s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.270s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.389s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.359s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.286s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.249s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.309s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.357s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.381s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.279s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.341s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.371s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.351s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.392s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.312s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.303s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.289s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.389s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.406s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.281s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.279s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.398s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.365s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.270s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.283s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.351s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.285s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.282s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.284s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.370s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.308s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.298s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.390s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.300s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.416s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.389s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.365s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.279s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.285s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.315s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.289s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.379s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.359s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.424s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.425s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.408s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.319s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.447s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.296s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.286s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.319s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.391s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.293s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.419s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.374s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.291s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.287s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.386s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.278s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.401s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.328s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.445s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.339s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.280s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.406s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.412s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.398s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.421s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.308s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.337s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.302s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.428s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.326s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.403s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.311s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.391s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.416s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.376s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.416s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.348s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.406s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.387s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.378s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.464s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.313s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.429s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.415s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.418s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.306s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.394s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.327s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.484s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.322s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.420s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.405s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.317s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.444s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.341s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.306s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.409s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.289s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.283s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.399s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.397s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.287s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.296s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.295s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.321s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.302s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.294s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.301s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.395s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.315s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.395s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.330s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.384s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.390s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.315s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.293s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.391s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.310s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.307s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.389s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.318s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.415s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.425s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.320s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.382s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.340s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.326s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.296s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.390s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.307s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.290s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.391s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.375s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.390s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.378s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.410s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.373s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.344s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.295s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.398s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.298s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.316s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.399s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.286s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.302s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.291s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.306s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.380s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.329s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.431s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.335s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.420s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.356s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.328s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.364s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.445s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.456s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.418s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.416s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.336s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.379s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.407s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.321s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.353s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.439s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.393s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.433s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.441s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.303s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.302s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.321s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.388s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.312s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.309s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.404s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.313s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.353s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.322s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.343s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.389s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.384s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.395s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.299s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.294s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.300s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.381s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.370s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.397s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.362s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.376s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.363s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.362s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.307s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.300s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.387s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.316s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.425s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.413s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.333s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.362s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.293s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.315s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.334s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.402s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.290s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.391s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.367s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.388s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.371s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.315s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.386s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.340s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.427s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.382s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.414s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.421s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.412s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.385s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.291s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.284s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.289s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.376s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.303s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.300s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.307s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.330s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.400s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.321s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.372s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.380s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.271s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.388s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.380s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.284s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.372s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.307s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.396s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.342s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.396s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.366s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.370s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.287s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.438s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.361s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.350s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.387s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.302s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.373s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.290s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.284s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.384s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.277s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.369s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.309s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.267s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.285s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.275s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.293s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.293s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.372s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.323s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.361s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.286s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.357s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.288s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.276s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.344s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.409s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.279s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.388s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.363s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.295s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.344s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.394s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.269s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.345s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.345s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.270s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.365s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.363s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.280s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.359s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.364s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.306s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.293s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.414s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.430s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.387s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.277s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.480s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.262s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.348s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.348s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.412s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.274s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.275s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.380s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.332s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.379s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.255s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.273s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.278s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.395s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.308s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.266s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.368s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.283s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.383s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.283s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.371s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.363s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.279s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.277s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.291s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.363s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.295s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.392s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.379s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.372s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.279s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.380s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.444s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.374s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.398s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.428s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.321s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.405s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.292s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.420s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.672s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.518s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.451s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.404s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.426s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.398s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.411s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.405s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.413s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.441s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.426s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.410s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.405s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.426s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.323s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.417s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.472s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.430s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.448s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.472s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.439s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.456s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.477s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.415s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.434s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.399s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.409s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.280s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.314s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.405s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.319s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.411s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.447s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.430s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.317s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.379s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.425s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.419s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.323s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.408s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.299s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.433s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.385s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.326s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.420s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.323s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.409s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.443s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.417s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.409s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.399s]
# ...
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.421s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.414s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.427s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.481s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.395s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.520s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.455s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.357s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.399s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.315s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.325s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.317s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.387s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.409s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.383s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.407s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.290s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.431s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.428s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.354s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.313s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.305s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.302s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.428s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.311s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.346s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.343s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.299s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.323s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.385s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.383s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.383s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.339s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.319s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.407s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.307s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.415s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.385s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.454s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.408s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.420s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.445s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.331s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.414s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.409s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.309s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.295s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.310s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.408s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.325s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.392s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.303s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.405s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.320s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.414s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.416s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.339s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.327s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.320s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.447s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.328s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.442s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.457s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.416s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.461s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.335s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.389s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.421s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.401s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.394s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.422s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.329s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.302s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.334s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.305s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.448s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.376s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.405s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.428s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.412s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.297s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.335s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.394s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.439s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.466s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.417s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.307s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.315s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.405s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.354s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.294s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.316s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.404s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.320s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.393s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.345s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.384s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.450s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.323s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.413s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.318s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.435s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.317s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.307s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.406s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.432s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.356s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.335s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.359s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.423s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.425s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.363s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.549s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.432s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.388s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.412s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.440s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.400s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.572s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.419s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.435s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.428s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.483s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.402s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.396s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.377s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.404s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.393s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.366s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.397s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.381s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:8.810s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.475s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.400s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.356s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_bulk [status:200 request:0.171s]
# (304135, [])

# %% [markdown]
# ## Get data from elastic search to pandas dataframe
#
# > * we use the search query here to get full documnet without any filters.(we will go through the queries in detail in further cells, here just trying to show that data can be uploaded and downloaded from pandas dataframe.)

# %%
print("The original shape of data is ", fb_outage_tweets_df.shape)
res = es.search(index = "facebook_outage_tweets")

data_from_es = pd.DataFrame(res["hits"]["hits"])
print("The shape of returned recieved data is ",data_from_es.shape,"\n")
data_from_es.head()
# Out:
# The original shape of data is  (304135, 36)
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.105s]
# The shape of returned recieved data is  (10, 6)
#                    _index  ... _ignored
# 0  facebook_outage_tweets  ...      NaN
# 1  facebook_outage_tweets  ...      NaN
# 2  facebook_outage_tweets  ...      NaN
# 3  facebook_outage_tweets  ...      NaN
# 4  facebook_outage_tweets  ...      NaN
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Pagination or scrolling over a index
#
# > * As we have seen above, we we do not give any JSON formatted query, it gets first 10 results of the index, the highest size we can get is 10,000 hits at once, we will not be able to get more than that at a time. We need to use scroll attribute of elastic search API to be able to receive more than 10,000 results.
#
# > * Another problem is the data is stored in _soucre of each item in new dataframe, which can be solved by using pandas to extract the data into columns.(That will not be shown here)

# %%
data = []
print("The original shape of data is ", fb_outage_tweets_df.shape)

res = es.search(index = "facebook_outage_tweets",size = 10000, scroll = "10m" )
data.extend(res["hits"]["hits"])
while(len(res["hits"]["hits"])):
  scroll_id = res['_scroll_id']
  res = es.scroll(scroll_id = scroll_id, scroll='10m')
  data.extend(res["hits"]["hits"])

data_from_es = pd.DataFrame(data)
print("The shape of returned recieved data is ",data_from_es.shape,"\n")
data_from_es.head()
# Out:
# The original shape of data is  (304135, 36)
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search?scroll=10m [status:200 request:1.088s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.498s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.518s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.528s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.457s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.480s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.552s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.463s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.572s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.493s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.478s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.465s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.520s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.469s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.462s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.498s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.537s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.477s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.499s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.514s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.530s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.596s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.583s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.484s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.492s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.474s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.474s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.518s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.474s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.468s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.224s]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/_search/scroll [status:200 request:0.095s]
# The shape of returned recieved data is  (304135, 6)
#                    _index  ... _ignored
# 0  facebook_outage_tweets  ...      NaN
# 1  facebook_outage_tweets  ...      NaN
# 2  facebook_outage_tweets  ...      NaN
# 3  facebook_outage_tweets  ...      NaN
# 4  facebook_outage_tweets  ...      NaN
#
# [5 rows x 6 columns]

# %% [markdown]
# # Querying in ElasticSearch (Let the fun begin!!)
#
# > * There are various ways in which a query can be written for text retrival in elastic search, but everything comes donw to one JSON object.
#
# > * Elasticsearch provides easy to use and different filters that can be used to model our query to return data as per requirements.
#
# > * A query in short is the POST request to our elasticsearch endpoint to retrive data.

# %% [markdown]
# ## First match query (like Hello world! in programming)
#
# > * The match query is used to match the term specified at any column of the table. we define what columns the search result should match in the match field of the JSON.
#
# > * By default th top 10 documents based on the query are returned, we can modify the size of the result to be returned by using size property.
#
# > * The output is not just the top 10 documents but some additional data is also displayed which is useful in understanding how the query has perfomed on our data.
#   >> * **_shards**: This dictionary tells us how many shards were queried and how many were successful.
#   >> * **hits**: This dictionary shows the total number of results matched and has an internal hits object for matched documents.
#   >>> * **total**: This dictionary holds the count of all matched documents and the relation that tells us if the count is accurate or not(i.e count  is either exactly equal if "eq" or less than or greater than if "lte" or "gte"). what ever the count, if size is not specified it returns 10 documents at once, we can get a maximum of 10000 documents at once in a single query.
#   >>> * **max_score**: This filed show the max score that was observed in all matches.
#   >>> * **hits**: This internal hits dictionary holds the full document that is ranked in that speicific position based on score.
#   >>>> * **_id**: is the unique id of each document or entry in the index.
#   >>>> * **_score**: is the score of the document based on the query. higher the score better the rank.
#   >>>>* **_source**: This dictionary has all the attributes of the entry or document of the matched document in the index.

# %%
# find the documents that has "signal" in the column "tweet".
query = {
    "match":{
        "tweet":"Signal"
        }
 }
es.search(query = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.027s]
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445136468247293962',
#     '_index': 'facebook_outage_tweets',
#     '_score': 10.717007,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445136468247293962,
#      'created_at': '2021-10-04 21:19:18 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebook', 'whatsapp', 'instagramdown', 'signal']",
#      'id': 1445136468247293962,
#      'language': 'und',
#      'likes_count': 0,
#      'link': 'https://twitter.com/omar_karbil/status/1445136468247293962',
#      'mentions': '[]',
#      'name': 'Omar Karbil',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:19:18',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'حملوا SIGNAl #Facebook #WhatsApp #instagramdown #Signal',
#      'urls': '[]',
#      'user_id': 1408065215267151872,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'omar_karbil',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127401831284739',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.61951,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127401831284739,
#      'created_at': '2021-10-04 20:43:16 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['signal', 'whatsapp', 'facebook', 'instagram']",
#      'id': 1445127401831284739,
#      'language': 'en',
#      'likes_count': 4,
#      'link': 'https://twitter.com/Darkcell17/status/1445127401831284739',
#      'mentions': "[{'screen_name': 'signalapp', 'name': 'signal', 'id': '142415193'}]",
#      'name': 'Darkcell',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/Snowden/status/1445090556388859904',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:43:16',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Signal &gt;Whatsapp+Telegram  I'm there too ....  #Signal #Whatsapp #Facebook #Instagram @signalapp",
#      'urls': '[]',
#      'user_id': 1056876667535323136,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'darkcell17',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127292548702219',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.61951,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127292548702219,
#      'created_at': '2021-10-04 20:42:50 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['apps', 'whatsapp', 'facebook', 'instagram', 'signal']",
#      'id': 1445127292548702219,
#      'language': 'es',
#      'likes_count': 0,
#      'link': 'https://twitter.com/Ady20_S/status/1445127292548702219',
#      'mentions': '[]',
#      'name': 'Adaly',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:42:50',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Alguien me cuenta qué es signal? 🤦\u200d♀️ #apps #WhatsApp #Facebook #instagram #Signal',
#      'urls': '[]',
#      'user_id': 332413279,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ady20_s',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137492047499277',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.9936905,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 21:23:22 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137492047499277,
#      'language': 'pt',
#      'likes_count': 1,
#      'link': 'https://twitter.com/H8TRV/status/1445137492047499277',
#      'mentions': '[]',
#      'name': '⚠️ 𝐓𝐇𝐄 𝐇𝐀𝐓𝐄𝐑 𝐕𝐈𝐑𝐔𝐒 ⚠️',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'scottyoung223', 'name': 'Scott young', 'id': '73919221'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:23:22',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@scottyoung223 @Facebook Telegram, Signal, email',
#      'urls': '[]',
#      'user_id': 2949680663,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'h8trv',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143173551075330',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445114730151043073,
#      'created_at': '2021-10-04 21:45:56 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143173551075330,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/AnonBlueCC/status/1445143173551075330',
#      'mentions': '[]',
#      'name': 'Richard Sanchez',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'schrep', 'name': 'Mike Schroepfer', 'id': '6182852'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:45:56',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@schrep @Facebook Use signal, use TOR',
#      'urls': '[]',
#      'user_id': 1071592301951107072,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'anonbluecc',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445136559704059913',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445136559704059913,
#      'created_at': '2021-10-04 21:19:39 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445136559704059913,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/DDamohill/status/1445136559704059913',
#      'mentions': '[]',
#      'name': 'O Samurai que acordou no lixão',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:19:39',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Instagram e Facebook 👎 Signal 👍',
#      'urls': '[]',
#      'user_id': 1335593093941387264,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ddamohill',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131231939768332',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131231939768332,
#      'created_at': '2021-10-04 20:58:29 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['signal', 'facebook', 'whatsapp']",
#      'id': 1445131231939768332,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/Hussein08552262/status/1445131231939768332',
#      'mentions': "[{'screen_name': 'elonmusk', 'name': 'elon musk', 'id': '44196397'}]",
#      'name': 'Hussein Photography',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:58:29',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Use #Signal Again @elonmusk  #facebook #WhatsApp',
#      'urls': '[]',
#      'user_id': 1020776811381260295,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'hussein08552262',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445129813157629954',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 20:52:51 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445129813157629954,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/nikosleov2/status/1445129813157629954',
#      'mentions': '[]',
#      'name': 'Nikos Schizodimos',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:52:51',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Facebook Signal and Telegram is better.',
#      'urls': '[]',
#      'user_id': 1407043791299751937,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nikosleov2',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445138593383686148',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.454069,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445114730151043073,
#      'created_at': '2021-10-04 21:27:44 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445138593383686148,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/NanEWallace/status/1445138593383686148',
#      'mentions': '[]',
#      'name': 'Nancy W',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'drogmaFB', 'name': 'Drogma', 'id': '812026824901464065'}, {'screen_name': 'schrep', 'name': 'Mike Schroepfer', 'id': '6182852'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:27:44',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@drogmaFB @schrep @Facebook Use signal or telegram.',
#      'urls': '[]',
#      'user_id': 2799535361,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nanewallace',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137038072745995',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.454069,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137038072745995,
#      'created_at': '2021-10-04 21:21:33 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137038072745995,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/IamFumnanya/status/1445137038072745995',
#      'mentions': '[]',
#      'name': 'Fumnanya 🇳🇬',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:21:33',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'SIGNAL app ...loading  Whatsapp Facebook Instagram... Away',
#      'urls': '[]',
#      'user_id': 408607836,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'iamfumnanya',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 10.717007,
#   'total': {'relation': 'eq', 'value': 545}},
#  'timed_out': False,
#  'took': 3}

# %% [markdown]
# ## Keeping track of Total matched documents
#
# > * We have seen above that hits has a total named dictionary that holds the count of matched documents(not the retrived documents), we only retrive a few documents, if 1000 are matched we only need first 100 or some arbitary value, so keeping a track of total is costly and we can skip if we want.
#
# > * The attribute "track_total_hits" helps us in keeping track of the total hits as needed.
# >> * If it is True, exact matched queries count is tracked and the relation will be "eq"
# >> * instead if the value is False while querying, we will not track this count at all.
# >> * Besides being a booleean value, the attribute can also be a integer. In this case, the total count till the integer value provided will be accurate but once it exceeds that value, it is not accurate.

# %%
# find the documents that has "signal" in the column "tweet".
query = {
    "track_total_hits":100,
    "query": {
    "match":{
        "tweet":"Signal"
        }
     }
     }
     
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.032s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   # This is added back by InteractiveShellApp.init_path()
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445136468247293962',
#     '_index': 'facebook_outage_tweets',
#     '_score': 10.717007,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445136468247293962,
#      'created_at': '2021-10-04 21:19:18 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebook', 'whatsapp', 'instagramdown', 'signal']",
#      'id': 1445136468247293962,
#      'language': 'und',
#      'likes_count': 0,
#      'link': 'https://twitter.com/omar_karbil/status/1445136468247293962',
#      'mentions': '[]',
#      'name': 'Omar Karbil',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:19:18',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'حملوا SIGNAl #Facebook #WhatsApp #instagramdown #Signal',
#      'urls': '[]',
#      'user_id': 1408065215267151872,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'omar_karbil',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127401831284739',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.61951,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127401831284739,
#      'created_at': '2021-10-04 20:43:16 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['signal', 'whatsapp', 'facebook', 'instagram']",
#      'id': 1445127401831284739,
#      'language': 'en',
#      'likes_count': 4,
#      'link': 'https://twitter.com/Darkcell17/status/1445127401831284739',
#      'mentions': "[{'screen_name': 'signalapp', 'name': 'signal', 'id': '142415193'}]",
#      'name': 'Darkcell',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/Snowden/status/1445090556388859904',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:43:16',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Signal &gt;Whatsapp+Telegram  I'm there too ....  #Signal #Whatsapp #Facebook #Instagram @signalapp",
#      'urls': '[]',
#      'user_id': 1056876667535323136,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'darkcell17',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127292548702219',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.61951,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127292548702219,
#      'created_at': '2021-10-04 20:42:50 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['apps', 'whatsapp', 'facebook', 'instagram', 'signal']",
#      'id': 1445127292548702219,
#      'language': 'es',
#      'likes_count': 0,
#      'link': 'https://twitter.com/Ady20_S/status/1445127292548702219',
#      'mentions': '[]',
#      'name': 'Adaly',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:42:50',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Alguien me cuenta qué es signal? 🤦\u200d♀️ #apps #WhatsApp #Facebook #instagram #Signal',
#      'urls': '[]',
#      'user_id': 332413279,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ady20_s',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137492047499277',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.9936905,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 21:23:22 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137492047499277,
#      'language': 'pt',
#      'likes_count': 1,
#      'link': 'https://twitter.com/H8TRV/status/1445137492047499277',
#      'mentions': '[]',
#      'name': '⚠️ 𝐓𝐇𝐄 𝐇𝐀𝐓𝐄𝐑 𝐕𝐈𝐑𝐔𝐒 ⚠️',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'scottyoung223', 'name': 'Scott young', 'id': '73919221'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:23:22',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@scottyoung223 @Facebook Telegram, Signal, email',
#      'urls': '[]',
#      'user_id': 2949680663,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'h8trv',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143173551075330',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445114730151043073,
#      'created_at': '2021-10-04 21:45:56 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143173551075330,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/AnonBlueCC/status/1445143173551075330',
#      'mentions': '[]',
#      'name': 'Richard Sanchez',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'schrep', 'name': 'Mike Schroepfer', 'id': '6182852'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:45:56',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@schrep @Facebook Use signal, use TOR',
#      'urls': '[]',
#      'user_id': 1071592301951107072,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'anonbluecc',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445136559704059913',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445136559704059913,
#      'created_at': '2021-10-04 21:19:39 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445136559704059913,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/DDamohill/status/1445136559704059913',
#      'mentions': '[]',
#      'name': 'O Samurai que acordou no lixão',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:19:39',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Instagram e Facebook 👎 Signal 👍',
#      'urls': '[]',
#      'user_id': 1335593093941387264,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ddamohill',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131231939768332',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131231939768332,
#      'created_at': '2021-10-04 20:58:29 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['signal', 'facebook', 'whatsapp']",
#      'id': 1445131231939768332,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/Hussein08552262/status/1445131231939768332',
#      'mentions': "[{'screen_name': 'elonmusk', 'name': 'elon musk', 'id': '44196397'}]",
#      'name': 'Hussein Photography',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:58:29',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Use #Signal Again @elonmusk  #facebook #WhatsApp',
#      'urls': '[]',
#      'user_id': 1020776811381260295,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'hussein08552262',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445129813157629954',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 20:52:51 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445129813157629954,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/nikosleov2/status/1445129813157629954',
#      'mentions': '[]',
#      'name': 'Nikos Schizodimos',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:52:51',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Facebook Signal and Telegram is better.',
#      'urls': '[]',
#      'user_id': 1407043791299751937,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nikosleov2',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445138593383686148',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.454069,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445114730151043073,
#      'created_at': '2021-10-04 21:27:44 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445138593383686148,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/NanEWallace/status/1445138593383686148',
#      'mentions': '[]',
#      'name': 'Nancy W',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'drogmaFB', 'name': 'Drogma', 'id': '812026824901464065'}, {'screen_name': 'schrep', 'name': 'Mike Schroepfer', 'id': '6182852'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:27:44',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@drogmaFB @schrep @Facebook Use signal or telegram.',
#      'urls': '[]',
#      'user_id': 2799535361,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nanewallace',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137038072745995',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.454069,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137038072745995,
#      'created_at': '2021-10-04 21:21:33 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137038072745995,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/IamFumnanya/status/1445137038072745995',
#      'mentions': '[]',
#      'name': 'Fumnanya 🇳🇬',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:21:33',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'SIGNAL app ...loading  Whatsapp Facebook Instagram... Away',
#      'urls': '[]',
#      'user_id': 408607836,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'iamfumnanya',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 10.717007,
#   'total': {'relation': 'gte', 'value': 100}},
#  'timed_out': False,
#  'took': 3}

# %% [markdown]
# ## The "Size" Attribute
# > * As mentioned before, if size attribute is not given, we will get a 10 results if matches are more than 10 and number of matches if they are less than 10.
# > * We can get a maximum of 10,000 documents at once, if we wnat more, we need to use scroll/pagination.
# > * if we set the size to zero, we can just check how many documents amtch the query.

# %%
query = {
    "match":{
        "tweet":"Signal"
        }
 }
es.search(query = query,index = "facebook_outage_tweets",size = 0)
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.025s]
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [],
#   'max_score': None,
#   'total': {'relation': 'eq', 'value': 545}},
#  'timed_out': False,
#  'took': 1}

# %% [markdown]
# ## Filtering Search results
# > * Filter attribute in our query will help in filtering and getting only the data that matches the filter as descriibed.
# > * term key in filter item is used when you have to check if a field has that term or not
# > * exists field is used to check if the field exists or not.
# > * range field is used when we want to search for range, less than or greater than
# > * match is used to check if the term or sentence matches in the given field.
# > * Filter is used inside bool attribute.

# %%
query = {
"track_total_hits":True,
"query":{
    "bool": {
      "filter": [
        { "term": { "language": "fr"}},
        {"exists":{"field":"tweet"}},
        {"range":{"replies_count":{"gte":10}}},
        {"match":{"tweet":"mark"}}

      ]
    }
 }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.029s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   app.launch_new_instance()
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445135556422377472',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445135556422377472,
#      'created_at': '2021-10-04 21:15:40 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445135556422377472,
#      'language': 'fr',
#      'likes_count': 1850,
#      'link': 'https://twitter.com/CurryElPatron/status/1445135556422377472',
#      'mentions': '[]',
#      'name': 'Shady',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 24,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 477,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/ext_tw_video_thumb/1445135096588210181/pu/img/whzbo1Ou6bPYTW7I.jpg',
#      'time': '21:15:40',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Mark Zuckerberg qui essaie de négocier avec Anonymous pour que Facebook, Instagram et WhatsApp soient réactivés  https://t.co/GbUoDPjgNt',
#      'urls': '[]',
#      'user_id': 1212474547,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'curryelpatron',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445137923259650055',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137923259650055,
#      'created_at': '2021-10-04 21:25:04 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137923259650055,
#      'language': 'fr',
#      'likes_count': 167,
#      'link': 'https://twitter.com/RTBFinfo/status/1445137923259650055',
#      'mentions': '[]',
#      'name': 'RTBF info',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 27,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 65,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:25:04',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'La panne de Facebook, Instagram et Whatsapp perdure: Mark Zuckerberg a perdu 7 milliards de dollars en quelques heures  https://t.co/y7zi4bihHP',
#      'urls': "['https://www.rtbf.be/info/medias/detail_la-panne-de-facebook-instagram-et-whatsapp-perdure-mark-zuckerberg-a-perdu-7-milliards-de-dollars-en-quelques-heures?id=10854199']",
#      'user_id': 14163474,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'rtbfinfo',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137515774685191',
#     '_ignored': ['tweet.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137515774685191,
#      'created_at': '2021-10-04 21:23:27 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebokdown', 'internetshutdown']",
#      'id': 1445137515774685191,
#      'language': 'fr',
#      'likes_count': 118,
#      'link': 'https://twitter.com/DFintelligence/status/1445137515774685191',
#      'mentions': '[]',
#      'name': 'Defend Intelligence',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4oNjiXMAMRFGf.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 16,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 52,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4oNjiXMAMRFGf.jpg',
#      'time': '21:23:27',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "🇺🇸Looks like the cause of #FacebokDown comes from the Metaverse installation which Mark Zuckerberg talked about a few days ago.  #internetShutDown  🇫🇷Apparement le down chez Facebook c'est pour l'installation du Metaverse dont Mark Zuckerberg a parlé il y a quelques semaines.  https://t.co/crm71gb5NN",
#      'urls': '[]',
#      'user_id': 1152543721138851840,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'dfintelligence',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445137515724353542',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137515724353542,
#      'created_at': '2021-10-04 21:23:27 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137515724353542,
#      'language': 'fr',
#      'likes_count': 37,
#      'link': 'https://twitter.com/JohanneMontay/status/1445137515724353542',
#      'mentions': "[{'screen_name': 'rtbf', 'name': 'rtbf', 'id': '14331898'}]",
#      'name': 'Johanne Montay',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 19,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 14,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:23:27',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'La panne de Facebook, Instagram et Whatsapp perdure: Mark Zuckerberg a perdu 7 milliards de dollars en quelques heures  https://t.co/nzvXOXibLF  via @RTBF',
#      'urls': "['https://www.rtbf.be/info/medias/detail_la-panne-de-facebook-instagram-et-whatsapp-perdure-mark-zuckerberg-a-perdu-7-milliards-de-dollars-en-quelques-heures?id=10854199']",
#      'user_id': 95434109,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'johannemontay',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445128391481511940',
#     '_ignored': ['tweet.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445128391481511940,
#      'created_at': '2021-10-04 20:47:12 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445128391481511940,
#      'language': 'fr',
#      'likes_count': 127,
#      'link': 'https://twitter.com/Moulathai_/status/1445128391481511940',
#      'mentions': '[]',
#      'name': 'Lee Fun Zu',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4gm7qXsAM3Nw_.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 18,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 56,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4gm7qXsAM3Nw_.jpg',
#      'time': '20:47:12',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '-Wesh Mark c’est quoi ce bordel la Face de Bouc ca bug 😂😂 -Frere Jsuis comme un ouf je crois c’est les anonymous de mon zeub la  -Ah oue chaud mais je te met 1 tarte pas 2 😂😂👋 -chauf moi pas Macaron 😡😡 -Ehh Mark Facebook est Sappé comme jamais, sappé comme jamais 🕺🕺🕺🕺  https://t.co/OzakXAo9BJ',
#      'urls': '[]',
#      'user_id': 1427613436167565327,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'moulathai_',
#      'video': 1},
#     '_type': '_doc'}],
#   'max_score': 0.0,
#   'total': {'relation': 'eq', 'value': 5}},
#  'timed_out': False,
#  'took': 7}

# %% [markdown]
# ## Aggregation
# > * Aggregration is used to group and analyze the data on a field.
# > * we will bring the count of top 10 highest tweeted conversationIds.
# > * Then we will also get the maximum likes in the top ten conversation-id tweets.
# > * These are just a few common items, there are different things that can be done with aggregation which can be found [here.](https://www.elastic.co/guide/en/elasticsearch/reference/current/search-aggregations-bucket-terms-aggregation.html)

# %%
  query = {
"track_total_hits":False,
"query":{
    "bool": {
      "filter": {"exists":{"field":"conversation_id"}}
    }
 },
 "aggs":{
     "MyBuckets":{
         "terms":{
             "field":"conversation_id",
             "order":{
                 "_count":"desc"
             },
             "size":10
         },"aggs": {
        "max_likes_count": { "max": { "field": "likes_count" } }
      }
     }
 },
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:22: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.532s]
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'MyBuckets': {'buckets': [{'doc_count': 5446,
#      'key': 1445061804636479493,
#      'max_likes_count': {'value': 835.0}},
#     {'doc_count': 3708,
#      'key': 1445114730151043073,
#      'max_likes_count': {'value': 720.0}},
#     {'doc_count': 1079,
#      'key': 1445078208190291973,
#      'max_likes_count': {'value': 23992.0}},
#     {'doc_count': 651,
#      'key': 1445104389014835213,
#      'max_likes_count': {'value': 332.0}},
#     {'doc_count': 418,
#      'key': 1445131408993923077,
#      'max_likes_count': {'value': 32586.0}},
#     {'doc_count': 376,
#      'key': 1445125556408836096,
#      'max_likes_count': {'value': 408.0}},
#     {'doc_count': 233,
#      'key': 1445066240817573903,
#      'max_likes_count': {'value': 1278.0}},
#     {'doc_count': 176,
#      'key': 1445060216161116168,
#      'max_likes_count': {'value': 37.0}},
#     {'doc_count': 170,
#      'key': 1445134713245601796,
#      'max_likes_count': {'value': 67045.0}},
#     {'doc_count': 158,
#      'key': 1445060225468297216,
#      'max_likes_count': {'value': 5.0}}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 291720}},
#  'hits': {'hits': [{'_id': '1445143573364498447',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143573364498447,
#      'created_at': '2021-10-04 21:47:32 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143573364498447,
#      'language': 'ja',
#      'likes_count': 0,
#      'link': 'https://twitter.com/DesignMatsukawa/status/1445143573364498447',
#      'mentions': '[]',
#      'name': 'Matsukawa-Design',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:32',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebookでシステム障害\u3000インスタなど世界で使えず: 日本経済新聞  https://t.co/ZJdXFS1riG',
#      'urls': "['https://www.nikkei.com/article/DGXZQOGN0500H0V01C21A0000000']",
#      'user_id': 1387660508887535620,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'designmatsukawa',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143573347852292',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143573347852292,
#      'created_at': '2021-10-04 21:47:32 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143573347852292,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/nandajjk_97/status/1445143573347852292',
#      'mentions': '[]',
#      'name': 'm⁷',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:32',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Whatsapp, Facebook, Instagram caíram  geral. Me: os verdadeiros  eu sei quem são',
#      'urls': '[]',
#      'user_id': 1424367583994724352,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nandajjk_97',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143573339545608',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143573339545608,
#      'created_at': '2021-10-04 21:47:32 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143573339545608,
#      'language': 'it',
#      'likes_count': 0,
#      'link': 'https://twitter.com/ANTONIO74119143/status/1445143573339545608',
#      'mentions': '[]',
#      'name': 'ANTONIO DONATO',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:32',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Non funziona Facebook',
#      'urls': '[]',
#      'user_id': 1440458001274470405,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'antonio74119143',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143573175980033',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143573175980033,
#      'created_at': '2021-10-04 21:47:31 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['secayotodo', 'buenlunes']",
#      'id': 1445143573175980033,
#      'language': 'es',
#      'likes_count': 0,
#      'link': 'https://twitter.com/AgNico13/status/1445143573175980033',
#      'mentions': '[]',
#      'name': 'Agüero Nico',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4uRQCWUAYVMq5.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4uRQCWUAYVMq5.jpg',
#      'time': '21:47:31',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'A qué hora vuelve WhatsApp, facebook, e Instagram? #secayotodo #buenlunes  https://t.co/oJd51UpnES',
#      'urls': '[]',
#      'user_id': 255554244,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'agnico13',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445143573175877638',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143573175877638,
#      'created_at': '2021-10-04 21:47:31 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143573175877638,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/MardeLenny/status/1445143573175877638',
#      'mentions': '[]',
#      'name': 'Mardê',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:31',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook voltou!',
#      'urls': '[]',
#      'user_id': 161760431,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'mardelenny',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143573167579139',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143573167579139,
#      'created_at': '2021-10-04 21:47:31 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143573167579139,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/camitalismo/status/1445143573167579139',
#      'mentions': '[]',
#      'name': 'camytian',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:31',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook não tá funcionando oh meu Deus e agora onde que arrumarei briga',
#      'urls': '[]',
#      'user_id': 838340503817043968,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'camitalismo',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143573138063369',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445141466750148616,
#      'created_at': '2021-10-04 21:47:31 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143573138063369,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/softlyhslot/status/1445143573138063369',
#      'mentions': '[]',
#      'name': 'pendles rolls royce',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'curlyjosty', 'name': 'jem !', 'id': '760432271803330560'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:31',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@curlyjosty i swear last time facebook was down my dad blamed the wifi',
#      'urls': '[]',
#      'user_id': 1248168731617837056,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'softlyhslot',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143573129748485',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143573129748485,
#      'created_at': '2021-10-04 21:47:31 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143573129748485,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/Laradajuju/status/1445143573129748485',
#      'mentions': '[]',
#      'name': 'Lαɾιɳԋα🌈',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:31',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'whatsap? cai facebook? cai instagram? cai twitter? cai mas sabe o que nunca vai cair? meu amor pelo Jaebeom',
#      'urls': '[]',
#      'user_id': 1268004412510830593,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'laradajuju',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143573087887375',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143573087887375,
#      'created_at': '2021-10-04 21:47:31 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143573087887375,
#      'language': 'pt',
#      'likes_count': 4,
#      'link': 'https://twitter.com/LarissaHayanna/status/1445143573087887375',
#      'mentions': '[]',
#      'name': 'Hay🦋',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 4,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:31',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook voltou só que tá bem lento',
#      'urls': '[]',
#      'user_id': 1268394710999142400,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'larissahayanna',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143572987084802',
#     '_ignored': ['tweet.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143572987084802,
#      'created_at': '2021-10-04 21:47:31 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143572987084802,
#      'language': 'en',
#      'likes_count': 235,
#      'link': 'https://twitter.com/KimZetter/status/1445143572987084802',
#      'mentions': '[]',
#      'name': 'Kim Zetter',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 4,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 125,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:31',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Given Facebook's outage was due to BGP routes being withdrawn, it's a good time to review what BGP is and how easily it can lead to outages. This story I wrote a while back is about hijacking traffic thru BGP, but it also discusses accidental outages   https://t.co/cH4dB0UaEm",
#      'urls': "['https://www.wired.com/2008/08/revealed-the-in/']",
#      'user_id': 48511236,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'kimzetter',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 0.0},
#  'timed_out': False,
#  'took': 506}

# %% [markdown]
# ## Get only required fields
# > * we can filter the data to return just that fields that are mentioned in the fields array.
# > * wildcard character can also be used.

# %%
query = {
  "query": {
    "match": {
      "tweet": "Mark"
    }
  },
  "fields": [
    "tweet",
    "replies_count",
    "retweet*"
  ],
  "_source": False
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.032s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445132497499607040',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.394503,
#     '_type': '_doc',
#     'fields': {'replies_count': [0],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ['Mark! Mark! Facebook is down.']}},
#    {'_id': '1445129213883953154',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.0430903,
#     '_type': '_doc',
#     'fields': {'replies_count': [0],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ["Mark Zuckerberg'in instagram ve facebook adresi Mark Zuckerberg."]}},
#    {'_id': '1445130053508022278',
#     '_index': 'facebook_outage_tweets',
#     '_score': 5.9343815,
#     '_type': '_doc',
#     'fields': {'replies_count': [0],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ['@kndlela55 Mark Facebook is down.  Mark:  https://t.co/WmA6brEf90']}},
#    {'_id': '1445143521103601667',
#     '_index': 'facebook_outage_tweets',
#     '_score': 5.8321576,
#     '_type': '_doc',
#     'fields': {'replies_count': [0],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ['Facebook Mark Zuckerberg Must Go To Jail "Handcuff  Mark Zuckerberg"  Guilty Man Mark Zuckerberg 🚨🚨🚨🤡']}},
#    {'_id': '1445136375217639437',
#     '_index': 'facebook_outage_tweets',
#     '_score': 5.821602,
#     '_type': '_doc',
#     'fields': {'replies_count': [0],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ['@Facebook @mark']}},
#    {'_id': '1445138197009285125',
#     '_index': 'facebook_outage_tweets',
#     '_score': 5.72829,
#     '_type': '_doc',
#     'fields': {'replies_count': [0],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ['Who is sabotaging Mark Zuckerberg Mark Zuckerberg #Facebook #WhatsApp #facebookdown #instagramdown']}},
#    {'_id': '1445131823638532104',
#     '_index': 'facebook_outage_tweets',
#     '_score': 5.72829,
#     '_type': '_doc',
#     'fields': {'replies_count': [0],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ['Mark Kapıyı Kitle Dayanırlar kapina #mark  #WpsiCokmusUserlerTakiplesiyor  #instagram  #Facebook  #çökmüş #guendem']}},
#    {'_id': '1445135559178039299',
#     '_index': 'facebook_outage_tweets',
#     '_score': 5.630521,
#     '_type': '_doc',
#     'fields': {'replies_count': [0],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ['@finkd Mark you been  acting like a hoe here lately #Facebook #Mark']}},
#    {'_id': '1445135213630083075',
#     '_index': 'facebook_outage_tweets',
#     '_score': 5.623138,
#     '_type': '_doc',
#     'fields': {'replies_count': [0],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ['Mark Cocksuckerberg @Facebook']}},
#    {'_id': '1445134224420442128',
#     '_index': 'facebook_outage_tweets',
#     '_score': 5.623138,
#     '_type': '_doc',
#     'fields': {'replies_count': [1],
#      'retweet': [False],
#      'retweet_date': ['-1'],
#      'retweet_date.keyword': ['-1'],
#      'retweet_id': ['-1'],
#      'retweet_id.keyword': ['-1'],
#      'retweets_count': [0],
#      'tweet': ['@sadshaytan MARK FACEBOOK']}}],
#   'max_score': 6.394503,
#   'total': {'relation': 'eq', 'value': 7509}},
#  'timed_out': False,
#  'took': 8}

# %% [markdown]
# ## Boolean Query
# > * **must**: The term must exist in the field, it contributes towards score.
# > * **filter**: The term must exist in the filed, but unlike must attribute it does not contribute towards score.
# > * **should**: The term should be  in the field, not compusary.
# >* **must_not**: The query is that matches the condition given will be excluded form scoring.
# > * **minimum_should_match**: This attribute can hold different typees of values,
# >> * Integer: Indicates a fixed value regardless of the number of optional clauses. example = 2
# >> * negative Integer: Indicates that the total number of optional clauses, minus this number should be mandatory. example = -3
# >> * Percentage: Indicates that this percent of the total number of optional clauses are necessary. The number computed from the percentage is rounded down and used as the minimum. Example = 75%
# >> * Negative percentage: Indicates that this percent of the total number of optional clauses can be missing. The number computed from the percentage is rounded down, before being subtracted from the total to determine the minimum.
# Example = -25%
# >> * Combination: A positive integer, followed by the less-than symbol, followed by any of the previously mentioned specifiers is a conditional specification. It indicates that if the number of optional clauses is equal to (or less than) the integer, they are all required, but if it’s greater than the integer, the specification applies. example = 3 < 90% In this example: if there are 1 to 3 clauses they are all required, but for 4 or more clauses only 90% are required.
# >> * Multiple combinations:Multiple conditional specifications can be separated by spaces, each one only being valid for numbers greater than the one before it.example - 2<-25% 9<-3, In this example: if there are 1 or 2 clauses both are required, if there are 3-9 clauses all but 25% are required, and if there are more than 9 clauses, all but three are required.

# %%
query = {
  "query": {
    "bool" : {
      "must" : {
        "term" : { "tweet" : "uninstall" }
      },
      "filter": {
        "term" : { "language" : "en" }
      },
      "must_not" : {
        "range" : {
          "replies_count" : { "gte" : 10, "lte" : 20 }
        }
      },
      "should" : [
        { "term" : { "timezone" : 0 } },
        { "term" : { "video" : 0 } }
      ],
      "minimum_should_match" : 1,
      "boost" : 1.0
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.033s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445127546270531596',
#     '_index': 'facebook_outage_tweets',
#     '_score': 15.512344,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127546270531596,
#      'created_at': '2021-10-04 20:43:50 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445127546270531596,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/dr5bludgeoning/status/1445127546270531596',
#      'mentions': '[]',
#      'name': 'i_amJeremy',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:43:50',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Uninstall Facebook.exe',
#      'urls': '[]',
#      'user_id': 810298107787431936,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'dr5bludgeoning',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445139575848976391',
#     '_index': 'facebook_outage_tweets',
#     '_score': 15.051697,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445139335448305681,
#      'created_at': '2021-10-04 21:31:38 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445139575848976391,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/eledoux/status/1445139575848976391',
#      'mentions': '[]',
#      'name': 'Ed Ledoux',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'sethmoulton', 'name': 'Seth Moulton', 'id': '248495200'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:31:38',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@sethmoulton @Facebook /uninstall',
#      'urls': '[]',
#      'user_id': 16856712,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'eledoux',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445133859444559872',
#     '_index': 'facebook_outage_tweets',
#     '_score': 14.62142,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445133859444559872,
#      'created_at': '2021-10-04 21:08:56 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['uninstall']",
#      'id': 1445133859444559872,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/mathew_zong/status/1445133859444559872',
#      'mentions': '[]',
#      'name': 'Big zong Mathew',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:08:56',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '#uninstall WhatsApp and Facebook',
#      'urls': '[]',
#      'user_id': 1445132735966683137,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'mathew_zong',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131424709947395',
#     '_index': 'facebook_outage_tweets',
#     '_score': 14.218609,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445118150069170179,
#      'created_at': '2021-10-04 20:59:15 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445131424709947395,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/Devin_the_guru/status/1445131424709947395',
#      'mentions': '[]',
#      'name': 'IamCasper™💀🍁',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'Psychoh_Sins', 'name': 'Psycho Sins💎🌠', 'id': '1270692014707871749'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:59:15',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Psychoh_Sins Uninstall Facebook 😂😂',
#      'urls': '[]',
#      'user_id': 1031663638384467968,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'devin_the_guru',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445134947958902784',
#     '_index': 'facebook_outage_tweets',
#     '_score': 13.619564,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445134947958902784,
#      'created_at': '2021-10-04 21:13:15 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['uninstallfacebookwhatsappinstrgram']",
#      'id': 1445134947958902784,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/DUAHU_RK/status/1445134947958902784',
#      'mentions': '[]',
#      'name': 'DUAHU_RK (AWAN Family|Daniش) 🇵🇰⚔️👽',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:13:15',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Now, wait is over 5 hours have been wasted to check socially.  Uninstall Whatsapp 💯  Uninstall Facebook 💯 Uninstall Instagram 💯  #UninstallFacebookWhatsappInstrgram  Copy this trend to hit the world's social media giants.",
#      'urls': '[]',
#      'user_id': 1245089420589576195,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'duahu_rk',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445135060911411207',
#     '_index': 'facebook_outage_tweets',
#     '_score': 13.503189,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445060216161116168,
#      'created_at': '2021-10-04 21:13:42 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['uninstallfacebookwhatsappinstrgram']",
#      'id': 1445135060911411207,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/DUAHU_RK/status/1445135060911411207',
#      'mentions': '[]',
#      'name': 'DUAHU_RK (AWAN Family|Daniش) 🇵🇰⚔️👽',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'WhatsApp', 'name': 'WhatsApp', 'id': '40148479'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:13:42',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "@WhatsApp Now, wait is over 5 hours have been wasted to check socially.  Uninstall Whatsapp 💯  Uninstall Facebook 💯 Uninstall Instagram 💯  #UninstallFacebookWhatsappInstrgram  Copy this trend to hit the world's social media giants.",
#      'urls': '[]',
#      'user_id': 1245089420589576195,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'duahu_rk',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445134599269593104',
#     '_index': 'facebook_outage_tweets',
#     '_score': 13.485493,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445134599269593104,
#      'created_at': '2021-10-04 21:11:52 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445134599269593104,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/lilhendrixvert/status/1445134599269593104',
#      'mentions': '[]',
#      'name': 'LuhhEarl',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:11:52',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Mightiest well uninstall Facebook&amp; Instagram 😒',
#      'urls': '[]',
#      'user_id': 800411889226240000,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'lilhendrixvert',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445133033040982018',
#     '_index': 'facebook_outage_tweets',
#     '_score': 13.150963,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445133033040982018,
#      'created_at': '2021-10-04 21:05:39 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445133033040982018,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/nudzbro/status/1445133033040982018',
#      'mentions': '[]',
#      'name': 'Mr Incredible',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:05:39',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'So, shall we just uninstall all Facebook apps?',
#      'urls': '[]',
#      'user_id': 20861070,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nudzbro',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445133910753558531',
#     '_index': 'facebook_outage_tweets',
#     '_score': 12.537148,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445133910753558531,
#      'created_at': '2021-10-04 21:09:08 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445133910753558531,
#      'language': 'en',
#      'likes_count': 9,
#      'link': 'https://twitter.com/ariadneconill/status/1445133910753558531',
#      'mentions': '[]',
#      'name': 'Ariadne Conill',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/BlazejKrajnak/status/1445063232486531099',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:09:08',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'just yet another reason to uninstall the facebook app, amirite?',
#      'urls': '[]',
#      'user_id': 15869538,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ariadneconill',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445132440822063106',
#     '_index': 'facebook_outage_tweets',
#     '_score': 12.537148,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445132440822063106,
#      'created_at': '2021-10-04 21:03:17 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445132440822063106,
#      'language': 'en',
#      'likes_count': 6,
#      'link': 'https://twitter.com/KieraKhadijah/status/1445132440822063106',
#      'mentions': '[]',
#      'name': 'kiera',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 2,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:03:17',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Everybody uninstall Facebook and then reinstall it. Let’s see sum',
#      'urls': '[]',
#      'user_id': 634119922,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'kierakhadijah',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 15.512344,
#   'total': {'relation': 'eq', 'value': 50}},
#  'timed_out': False,
#  'took': 11}

# %% [markdown]
# ## Score boosting
#
# > * we can decrease the score of the required terms or phrases as required.
# > * below query adds to the score when "signal" matches in tweet and decreases the relevence score by penalizing the terms that exists in negative field.
# > * boost value ranges form 0 to 1 only.

# %%
query = {
  "query": {
    "boosting": {
      "positive": {
        "match": {
          "tweet": "Signal"
        }
      },
      "negative": {
        "term": {
          "text": "facebook"
        }
      },
      "negative_boost": 0.8,
      "negative": {
        "term": {
          "text": "watsapp"
        }
      },
      "negative_boost": 0.3,
      "negative": {
        "term": {
          "text": "instagram"
        }
      },
      "negative_boost": 0.5
      
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.028s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:31: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445136468247293962',
#     '_index': 'facebook_outage_tweets',
#     '_score': 10.717007,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445136468247293962,
#      'created_at': '2021-10-04 21:19:18 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebook', 'whatsapp', 'instagramdown', 'signal']",
#      'id': 1445136468247293962,
#      'language': 'und',
#      'likes_count': 0,
#      'link': 'https://twitter.com/omar_karbil/status/1445136468247293962',
#      'mentions': '[]',
#      'name': 'Omar Karbil',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:19:18',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'حملوا SIGNAl #Facebook #WhatsApp #instagramdown #Signal',
#      'urls': '[]',
#      'user_id': 1408065215267151872,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'omar_karbil',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127401831284739',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.61951,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127401831284739,
#      'created_at': '2021-10-04 20:43:16 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['signal', 'whatsapp', 'facebook', 'instagram']",
#      'id': 1445127401831284739,
#      'language': 'en',
#      'likes_count': 4,
#      'link': 'https://twitter.com/Darkcell17/status/1445127401831284739',
#      'mentions': "[{'screen_name': 'signalapp', 'name': 'signal', 'id': '142415193'}]",
#      'name': 'Darkcell',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/Snowden/status/1445090556388859904',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:43:16',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Signal &gt;Whatsapp+Telegram  I'm there too ....  #Signal #Whatsapp #Facebook #Instagram @signalapp",
#      'urls': '[]',
#      'user_id': 1056876667535323136,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'darkcell17',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127292548702219',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.61951,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127292548702219,
#      'created_at': '2021-10-04 20:42:50 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['apps', 'whatsapp', 'facebook', 'instagram', 'signal']",
#      'id': 1445127292548702219,
#      'language': 'es',
#      'likes_count': 0,
#      'link': 'https://twitter.com/Ady20_S/status/1445127292548702219',
#      'mentions': '[]',
#      'name': 'Adaly',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:42:50',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Alguien me cuenta qué es signal? 🤦\u200d♀️ #apps #WhatsApp #Facebook #instagram #Signal',
#      'urls': '[]',
#      'user_id': 332413279,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ady20_s',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137492047499277',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.9936905,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 21:23:22 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137492047499277,
#      'language': 'pt',
#      'likes_count': 1,
#      'link': 'https://twitter.com/H8TRV/status/1445137492047499277',
#      'mentions': '[]',
#      'name': '⚠️ 𝐓𝐇𝐄 𝐇𝐀𝐓𝐄𝐑 𝐕𝐈𝐑𝐔𝐒 ⚠️',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'scottyoung223', 'name': 'Scott young', 'id': '73919221'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:23:22',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@scottyoung223 @Facebook Telegram, Signal, email',
#      'urls': '[]',
#      'user_id': 2949680663,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'h8trv',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143173551075330',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445114730151043073,
#      'created_at': '2021-10-04 21:45:56 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143173551075330,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/AnonBlueCC/status/1445143173551075330',
#      'mentions': '[]',
#      'name': 'Richard Sanchez',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'schrep', 'name': 'Mike Schroepfer', 'id': '6182852'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:45:56',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@schrep @Facebook Use signal, use TOR',
#      'urls': '[]',
#      'user_id': 1071592301951107072,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'anonbluecc',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445136559704059913',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445136559704059913,
#      'created_at': '2021-10-04 21:19:39 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445136559704059913,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/DDamohill/status/1445136559704059913',
#      'mentions': '[]',
#      'name': 'O Samurai que acordou no lixão',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:19:39',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Instagram e Facebook 👎 Signal 👍',
#      'urls': '[]',
#      'user_id': 1335593093941387264,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ddamohill',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131231939768332',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131231939768332,
#      'created_at': '2021-10-04 20:58:29 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['signal', 'facebook', 'whatsapp']",
#      'id': 1445131231939768332,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/Hussein08552262/status/1445131231939768332',
#      'mentions': "[{'screen_name': 'elonmusk', 'name': 'elon musk', 'id': '44196397'}]",
#      'name': 'Hussein Photography',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:58:29',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Use #Signal Again @elonmusk  #facebook #WhatsApp',
#      'urls': '[]',
#      'user_id': 1020776811381260295,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'hussein08552262',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445129813157629954',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.715534,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 20:52:51 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445129813157629954,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/nikosleov2/status/1445129813157629954',
#      'mentions': '[]',
#      'name': 'Nikos Schizodimos',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:52:51',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Facebook Signal and Telegram is better.',
#      'urls': '[]',
#      'user_id': 1407043791299751937,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nikosleov2',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445138593383686148',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.454069,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445114730151043073,
#      'created_at': '2021-10-04 21:27:44 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445138593383686148,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/NanEWallace/status/1445138593383686148',
#      'mentions': '[]',
#      'name': 'Nancy W',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'drogmaFB', 'name': 'Drogma', 'id': '812026824901464065'}, {'screen_name': 'schrep', 'name': 'Mike Schroepfer', 'id': '6182852'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:27:44',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@drogmaFB @schrep @Facebook Use signal or telegram.',
#      'urls': '[]',
#      'user_id': 2799535361,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nanewallace',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137038072745995',
#     '_index': 'facebook_outage_tweets',
#     '_score': 8.454069,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137038072745995,
#      'created_at': '2021-10-04 21:21:33 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137038072745995,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/IamFumnanya/status/1445137038072745995',
#      'mentions': '[]',
#      'name': 'Fumnanya 🇳🇬',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:21:33',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'SIGNAL app ...loading  Whatsapp Facebook Instagram... Away',
#      'urls': '[]',
#      'user_id': 408607836,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'iamfumnanya',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 10.717007,
#   'total': {'relation': 'eq', 'value': 545}},
#  'timed_out': False,
#  'took': 4}

# %% [markdown]
# ## Intervals Query
# > * Returns documents based on the order and proximity of matching terms.
# > * **all_of**: the mathcing document must hav the phrase in this segment.
# > * **any_of**: the matching document will have any of the matching query in this segment.
# > * **Max_gaps**: this provides the spcae between the first phrse and other phrases that can be there.

# %%
query = {
  "query": {
    "intervals" : {
      "tweet" : {
        "all_of" : {
          "ordered" : True,
          "intervals" : [
            {
              "match" : {
                "query" : "My first Tweet ever because",
                "max_gaps" : 0,
                "ordered" : True
              }
            },
            {
              "any_of" : {
                "intervals" : [
                  { "match" : { "query" : " Facebook is down! " } },
                  { "match" : { "query" : "watsapp is not working" } }
                ]
              }
            }
          ]
        }
      }
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.201s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445142277249290241',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.5,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445142277249290241,
#      'created_at': '2021-10-04 21:42:22 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445142277249290241,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/lovedhim78/status/1445142277249290241',
#      'mentions': '[]',
#      'name': 'Joy Davis',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:42:22',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'My first Tweet ever because Facebook is down!',
#      'urls': '[]',
#      'user_id': 1445137725825470464,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'lovedhim78',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 0.5,
#   'total': {'relation': 'eq', 'value': 1}},
#  'timed_out': False,
#  'took': 76}

# %% [markdown]
# ## Match phrase query
#
# > * This attribute is used to match the query that has exact same phrase in it.
# > * Those document that has this term and some prefix or suffix to it also match the query.

# %%
query = {
  "query": {
    "match_phrase": {
      "tweet": "the Facebook shutdown"
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.221s]
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445128574407675915',
#     '_index': 'facebook_outage_tweets',
#     '_score': 10.944517,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445128574407675915,
#      'created_at': '2021-10-04 20:47:55 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445128574407675915,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/theguykt/status/1445128574407675915',
#      'mentions': '[]',
#      'name': 'kt.',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/nocontextdrumar/status/1445085983335231493',
#      'replies_count': 1,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:47:55',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'This caused the Facebook shutdown',
#      'urls': '[]',
#      'user_id': 3306381432,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'theguykt',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131709503131654',
#     '_index': 'facebook_outage_tweets',
#     '_score': 10.606026,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131709503131654,
#      'created_at': '2021-10-04 21:00:23 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445131709503131654,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/JuggaloHomie810/status/1445131709503131654',
#      'mentions': '[]',
#      'name': 'Bobby Davidson #BBTG',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:00:23',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "LOL'ing at the Facebook shutdown 😂",
#      'urls': '[]',
#      'user_id': 749802484055638016,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'juggalohomie810',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127207085494274',
#     '_index': 'facebook_outage_tweets',
#     '_score': 10.287846,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127207085494274,
#      'created_at': '2021-10-04 20:42:29 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445127207085494274,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/DavidDennison/status/1445127207085494274',
#      'mentions': '[]',
#      'name': 'David Dennison',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/blaireerskine/status/1445055792365723659',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:42:29',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Most underrated tweet about the Facebook shutdown',
#      'urls': '[]',
#      'user_id': 1299403600737624064,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'daviddennison',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445135471835848715',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.988199,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445135471835848715,
#      'created_at': '2021-10-04 21:15:20 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445135471835848715,
#      'language': 'en',
#      'likes_count': 11,
#      'link': 'https://twitter.com/oracIesbat/status/1445135471835848715',
#      'mentions': '[]',
#      'name': '.',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/ext_tw_video_thumb/1445054998044307467/pu/img/O5PRwv37s1pV5PWS.jpg',
#      'time': '21:15:20',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'this caused the facebook shutdown   https://t.co/gwULyqpH3i',
#      'urls': '[]',
#      'user_id': 1270395492732723205,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'oraciesbat',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445139562779525136',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.43839,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445139562779525136,
#      'created_at': '2021-10-04 21:31:35 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445139562779525136,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/nebasaurousrex/status/1445139562779525136',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': '60minutes', 'name': '60 minutes', 'id': '18812572'}]",
#      'name': 'Bennett',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:31:35',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'The @Facebook shutdown is a distraction from the @60Minutes whistleblower',
#      'urls': '[]',
#      'user_id': 715358990310498304,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nebasaurousrex',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445135142117314562',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.43839,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445135142117314562,
#      'created_at': '2021-10-04 21:14:01 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445135142117314562,
#      'language': 'en',
#      'likes_count': 3,
#      'link': 'https://twitter.com/MikeKMorrison/status/1445135142117314562',
#      'mentions': '[]',
#      'name': 'Mike Morrison \U0001f9ac',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:14:01',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Good info on the Facebook shutdown here  https://t.co/t1XxsfRMaD',
#      'urls': "['https://twitter.com/i/spaces/1ZkJzbMjLBeJv']",
#      'user_id': 46587597,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'mikekmorrison',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445139114882437124',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.1855755,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445139114882437124,
#      'created_at': '2021-10-04 21:29:49 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445139114882437124,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/eichi_master/status/1445139114882437124',
#      'mentions': '[]',
#      'name': 'mat',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:29:49',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'the facebook shutdown sounds like the awakening of a new enemy',
#      'urls': '[]',
#      'user_id': 719143752875577344,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'eichi_master',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137435873234946',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.1855755,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137033706496004,
#      'created_at': '2021-10-04 21:23:08 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137435873234946,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/BunWizard_Tammy/status/1445137435873234946',
#      'mentions': '[]',
#      'name': 'Julian, the Chaotic Diety of Bois',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'TheCedarForge', 'name': '🍂💀ᛃThe Cedar Forgeᛃ💀🍁He/Him', 'id': '1247731173893255168'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:23:08',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@TheCedarForge another good thing that came out of the facebook shutdown',
#      'urls': '[]',
#      'user_id': 2546958284,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'bunwizard_tammy',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445134265138569224',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.1855755,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445134265138569224,
#      'created_at': '2021-10-04 21:10:32 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445134265138569224,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/joseifanboy/status/1445134265138569224',
#      'mentions': '[]',
#      'name': 'I STAN COLD BLACKSHORTHAIRED WAIFU',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:10:32',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "someone's supposed to be studying and now's investing the facebook shutdown",
#      'urls': '[]',
#      'user_id': 1309916580323622912,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'joseifanboy',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445129530960605185',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.1855755,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445129530960605185,
#      'created_at': '2021-10-04 20:51:44 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['tiktok']",
#      'id': 1445129530960605185,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/phreshchrisofla/status/1445129530960605185',
#      'mentions': '[]',
#      'name': 'PhreshChrisofLA ⚡️',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:51:44',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'The world during the Facebook Shutdown LOL #TikTok  https://t.co/3alACvAowO',
#      'urls': "['https://vm.tiktok.com/ZMRKrDmLp/']",
#      'user_id': 1291605176596361217,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'phreshchrisofla',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 10.944517,
#   'total': {'relation': 'eq', 'value': 49}},
#  'timed_out': False,
#  'took': 31}

# %% [markdown]
# ## Match phrase prefix query
# > * Returns documents that contain the words of a provided text, in the same order as provided. The last term of the provided text is treated as a prefix, matching any words that begin with that term.

# %%
query = {
  "query": {
    "match_phrase_prefix": {
      "tweet": {
        "query": "Facebook s",
      }
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.041s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   # Remove the CWD from sys.path while we load stuff.
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445143350252822536',
#     '_index': 'facebook_outage_tweets',
#     '_score': 791.3332,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445114730151043073,
#      'created_at': '2021-10-04 21:46:38 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143350252822536,
#      'language': 'und',
#      'likes_count': 0,
#      'link': 'https://twitter.com/Omeed_Shahab/status/1445143350252822536',
#      'mentions': '[]',
#      'name': 'Omeed-Shahab-Hamad',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'schrep', 'name': 'Mike Schroepfer', 'id': '6182852'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:46:38',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@schrep @Facebook s',
#      'urls': '[]',
#      'user_id': 1430288364595449859,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'omeed_shahab',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127493695025161',
#     '_index': 'facebook_outage_tweets',
#     '_score': 765.24524,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445072756484231181,
#      'created_at': '2021-10-04 20:43:38 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445127493695025161,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/cookster1953/status/1445127493695025161',
#      'mentions': '[]',
#      'name': 'gerald cook',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'bblock29', 'name': 'Agolf Twitler Slayer', 'id': '1949789970'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:43:38',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@bblock29 What’s Facebook? /s',
#      'urls': '[]',
#      'user_id': 763075820,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'cookster1953',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445132179542093830',
#     '_index': 'facebook_outage_tweets',
#     '_score': 740.8226,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445075316523905024,
#      'created_at': '2021-10-04 21:02:15 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebook']",
#      'id': 1445132179542093830,
#      'language': 'sv',
#      'likes_count': 1,
#      'link': 'https://twitter.com/casanor11/status/1445132179542093830',
#      'mentions': '[]',
#      'name': 'NatteramnGjenferd',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': "[{'screen_name': 'grevlingmamma', 'name': 'Grevlingmamma 🦡', 'id': '1213479639496060928'}, {'screen_name': 'StleKvale', 'name': 'Ståle', 'id': '331904434'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:02:15',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@grevlingmamma @StleKvale #Facebook sa det',
#      'urls': '[]',
#      'user_id': 1343500261982089216,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'casanor11',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131060182933504',
#     '_index': 'facebook_outage_tweets',
#     '_score': 717.9105,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131060182933504,
#      'created_at': '2021-10-04 20:57:48 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445131060182933504,
#      'language': 'fr',
#      'likes_count': 0,
#      'link': 'https://twitter.com/becherbessadok/status/1445131060182933504',
#      'mentions': '[]',
#      'name': 'becher',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4jCQ6WEAg73Wf.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4jCQ6WEAg73Wf.jpg',
#      'time': '20:57:48',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook s effondre  https://t.co/uOGHNEknUu',
#      'urls': '[]',
#      'user_id': 304656369,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'becherbessadok',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445130147208773636',
#     '_index': 'facebook_outage_tweets',
#     '_score': 696.37317,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445129694773497862,
#      'created_at': '2021-10-04 20:54:10 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445130147208773636,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/heyitsjoao/status/1445130147208773636',
#      'mentions': '[]',
#      'name': 'joão',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'lluanfe', 'name': 'lu an?', 'id': '1340842703194632196'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:54:10',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@lluanfe o domínio do facebook s venda',
#      'urls': '[]',
#      'user_id': 1225948642009321472,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'heyitsjoao',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127445598904331',
#     '_index': 'facebook_outage_tweets',
#     '_score': 696.37317,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127445598904331,
#      'created_at': '2021-10-04 20:43:26 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445127445598904331,
#      'language': 'cs',
#      'likes_count': 8,
#      'link': 'https://twitter.com/prirovnej/status/1445127445598904331',
#      'mentions': '[]',
#      'name': 'Přirovnej.cz',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:43:26',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Je v prdeli jak Facebook s Instagramem.',
#      'urls': '[]',
#      'user_id': 305275147,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'prirovnej',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445135503335071756',
#     '_index': 'facebook_outage_tweets',
#     '_score': 676.09045,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445135503335071756,
#      'created_at': '2021-10-04 21:15:27 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebookhacked', 'facebookdown', 'facebookhack']",
#      'id': 1445135503335071756,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/RiderFx3/status/1445135503335071756',
#      'mentions': '[]',
#      'name': 'Romain GALVEZ',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:15:27',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Facebook s'est fait Zuck' 😂 #facebookhacked #facebookdown #facebookhack",
#      'urls': '[]',
#      'user_id': 919202413004902400,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'riderfx3',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445142804724862979',
#     '_index': 'facebook_outage_tweets',
#     '_score': 676.09045,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445142804724862979,
#      'created_at': '2021-10-04 21:44:28 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445142804724862979,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/NBAisBest4/status/1445142804724862979',
#      'mentions': '[]',
#      'name': 'NBA Discussion',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4tt1TXoAEfL4y.png']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4tt1TXoAEfL4y.png',
#      'time': '21:44:28',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Me at Facebook`s Funeral  https://t.co/KV4y9Yxbh7',
#      'urls': '[]',
#      'user_id': 1210566639005114371,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'nbaisbest4',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445138950998401027',
#     '_index': 'facebook_outage_tweets',
#     '_score': 676.09045,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445138950998401027,
#      'created_at': '2021-10-04 21:29:09 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebook']",
#      'id': 1445138950998401027,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/GlennAston/status/1445138950998401027',
#      'mentions': '[]',
#      'name': 'Glenn Aston',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:29:09',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '$47bn knocked off #facebook ‘s market value. Ouch',
#      'urls': '[]',
#      'user_id': 82937450,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'glennaston',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445138131213332483',
#     '_index': 'facebook_outage_tweets',
#     '_score': 676.09045,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445138131213332483,
#      'created_at': '2021-10-04 21:25:54 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445138131213332483,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/ally_unsaid/status/1445138131213332483',
#      'mentions': '[]',
#      'name': 'Ally🤰🎃🦹🕸️💀',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:25:54',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "@Facebook 's twitter account views today 📈📈",
#      'urls': '[]',
#      'user_id': 2914948654,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ally_unsaid',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 791.3332,
#   'total': {'relation': 'eq', 'value': 135}},
#  'timed_out': False,
#  'took': 17}

# %% [markdown]
# ## Multi macth query
# > * The multi_match query builds on the match query to allow multi-field queries.

# %%
query = {
  "query": {
    "multi_match" : {
      "query": "facebook", 
      "fields": [ "tweet", "mentions" ] 
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.040s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   if __name__ == '__main__':
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445128160534749196',
#     '_ignored': ['mentions.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.4122502,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445128160534749196,
#      'created_at': '2021-10-04 20:46:17 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445128160534749196,
#      'language': 'es',
#      'likes_count': 0,
#      'link': 'https://twitter.com/ALEXANDERCALLAO/status/1445128160534749196',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'Alexander \uea00',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:46:17',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '🖕🏼Esta pa @Facebook 🖕🏼Esta pa @Facebook 🖕🏼Esta pa @Facebook🖕🏼Esta pa @Facebook 🖕🏼Esta pa @Facebook 🖕🏼Esta pa @Facebook🖕🏼Esta pa @Facebook 🖕🏼Esta pa @Facebook 🖕🏼Esta pa @Facebook',
#      'urls': '[]',
#      'user_id': 593985277,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'alexandercallao',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445135786014281742',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.3498304,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445135786014281742,
#      'created_at': '2021-10-04 21:16:35 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445135786014281742,
#      'language': 'en',
#      'likes_count': 2,
#      'link': 'https://twitter.com/ChrisSigler6/status/1445135786014281742',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'Chris Sigler',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 2,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:16:35',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'I have so much more free time now that @Facebook is down and I’d love to post something about that and let my @Facebook followers know but …',
#      'urls': '[]',
#      'user_id': 1040980782385426432,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'chrissigler6',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445139779968901130',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.3498304,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445066240817573903,
#      'created_at': '2021-10-04 21:32:27 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445139779968901130,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/Shaunasmom23/status/1445139779968901130',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'Linda Gillam',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': "[{'screen_name': 'AP', 'name': 'The Associated Press', 'id': '51241574'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:32:27',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "@AP Good!!! @Facebook wouldn't help me recover my account that was hacked.. THANK YOU KARMA!!  BYE @Facebook",
#      'urls': '[]',
#      'user_id': 1443263223315062785,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'shaunasmom23',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445139490868187137',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.3498304,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445139490868187137,
#      'created_at': '2021-10-04 21:31:18 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['gottagetright', 'zuckerbergdown']",
#      'id': 1445139490868187137,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/1017Rebel/status/1445139490868187137',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': '1017Rebel',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:31:18',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Yesterday’s @Facebook is not today’s @Facebook  #gottagetright #Zuckerbergdown',
#      'urls': '[]',
#      'user_id': 300605653,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': '1017rebel',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445138517332529170',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.3498304,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445138517332529170,
#      'created_at': '2021-10-04 21:27:26 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445138517332529170,
#      'language': 'en',
#      'likes_count': 3,
#      'link': 'https://twitter.com/_LKC_/status/1445138517332529170',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'Lori in Vermont',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/alexhern/status/1445130867073032195',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:27:26',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'If accurate, this is literally analogous to what happens when a hacker hacks your @Facebook and renders you powerless because *solutions require that you be logged into @Facebook* !!!!!!!!!',
#      'urls': '[]',
#      'user_id': 190340855,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': '_lkc_',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445138371261566976',
#     '_ignored': ['tweet.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.3498304,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445099150316503057,
#      'created_at': '2021-10-04 21:26:51 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445138371261566976,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/Noah_A_S/status/1445138371261566976',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'Noah #AR#VR#MR#XR👓#LeapNation👾#LEAPCon2🍫🍫🎫😎',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': "[{'screen_name': 'HousAtlntaVegas', 'name': 'Houston', 'id': '446755826'}, {'screen_name': 'Jaat__Shaab', 'name': 'Mr_tomar', 'id': '1379085950752419842'}, {'screen_name': 'sheeraf', 'name': 'Sheera Frenkel', 'id': '20052487'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:26:51',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@HousAtlntaVegas @Jaat__Shaab @sheeraf At this point, it feels more like someone from *higher up* or *above board* did or is doing something to cause all of these outages because there were (developing) fears that @Facebook has become a threat to national security.  Or maybe it is just starting w/ @Facebook.',
#      'urls': '[]',
#      'user_id': 2946893125,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'noah_a_s',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137025426939917',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.3498304,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137025426939917,
#      'created_at': '2021-10-04 21:21:30 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['ihaveaproblem']",
#      'id': 1445137025426939917,
#      'language': 'en',
#      'likes_count': 23,
#      'link': 'https://twitter.com/LauraMonteverdi/status/1445137025426939917',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'Laura Monteverdi',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 4,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:21:30',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'I just went to @Facebook to ask people what they were doing with their free time with @Facebook down. #Ihaveaproblem',
#      'urls': '[]',
#      'user_id': 442043313,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'lauramonteverdi',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445136237224939523',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.3498304,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445136237224939523,
#      'created_at': '2021-10-04 21:18:22 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445136237224939523,
#      'language': 'ar',
#      'likes_count': 25,
#      'link': 'https://twitter.com/Pacifista_1/status/1445136237224939523',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'Nessim 🇹🇳',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 5,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:18:22',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'عندي اقتراح للخبراء متاع شركة فايسبوك علاش ما تقصوش الضو و ترجعوه هو نحنا في تونس كي يصير مشكل نعملوها الفازة و تنجح جربوها باز تنجح  @Facebook  @Facebook',
#      'urls': '[]',
#      'user_id': 2167433296,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'pacifista_1',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445133450688798734',
#     '_ignored': ['tweet.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.3498304,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445133450688798734,
#      'created_at': '2021-10-04 21:07:18 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445133450688798734,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/MakaiaNambale/status/1445133450688798734',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'Makaia Nambale',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/Facebook/status/1445061804636479493?s=20',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:07:18',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Tweet from Facebook (@Facebook) Facebook (@Facebook) Tweeted: We’re aware that some people are having trouble accessing our apps and products. We’re working to get things back to normal as quickly as possible, and we apologize for any inconvenience.  https://t.co/BiNWUu1kTG',
#      'urls': "['https://twitter.com/Facebook/status/1445061804636479493?s=20']",
#      'user_id': 1445132311079620626,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'makaianambale',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445133315892293634',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.3498304,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445133315892293634,
#      'created_at': '2021-10-04 21:06:46 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445133315892293634,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/MariMoon888/status/1445133315892293634',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'Mari Monteiro',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:06:46',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Estou sentindo falta de polemizar aa quedas do @Facebook no próprio @Facebook 🤭😂',
#      'urls': '[]',
#      'user_id': 1445130004673830923,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'marimoon888',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 1.4122502,
#   'total': {'relation': 'gte', 'value': 10000}},
#  'timed_out': False,
#  'took': 17}

# %% [markdown]
# ##Specialized queries(Distance feature query)
# > * Boosts the relevance score of documents closer to a provided origin date or point. For example, you can use this query to give more weight to documents closer to a certain date or location.
# > * You can use the distance_feature query to find the nearest neighbors to a location. You can also use the query in a bool search’s should filter to add boosted relevance scores to the bool query’s scores.
# > * The attributes used are described as below,
# >> * **field**: This can be used to store date or geolocation.
# >> * **origin**: This is the point of reference form where the current value distace has to be measured.
# >> * **pivot**: Distance from the origin at which relevance scores receive half of the boost value
# >> * **boost**: Floating point number used to multiply the relevance score of matching documents. This value cannot be negative. Defaults to 1.0.

# %%
 query = {
  "query": {
    "bool": {
      "must": {
        "match": {
          "tweet": "facebook is down"
        }
      },
      "should": {
        "distance_feature": {
          "field": "date",
          "pivot": "7d",
          "origin": "now",
          "boost":0.5
        }
      }
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.496s]
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445126990202380298',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.948606,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445126990202380298,
#      'created_at': '2021-10-04 20:41:38 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445126990202380298,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/yoncesmegan/status/1445126990202380298',
#      'mentions': '[]',
#      'name': 'Charlie 🐝🐝',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:41:38',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'instagram is down  twitter is down  google is down facebook is down whatsapp is down yoncesmegan is still standing.',
#      'urls': '[]',
#      'user_id': 1336411085977563148,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'yoncesmegan',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445133846236762127',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.945816,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445133846236762127,
#      'created_at': '2021-10-04 21:08:52 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445133846236762127,
#      'language': 'en',
#      'likes_count': 3,
#      'link': 'https://twitter.com/tbbminaj/status/1445133846236762127',
#      'mentions': '[]',
#      'name': 'shabz | shalano era (2yr poshiey mootiversary)',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:08:52',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'instagram is down  twitter is down  google is down facebook is down whatsapp is down Shabz was always down :/',
#      'urls': '[]',
#      'user_id': 1211775258354569216,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'tbbminaj',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445141241348378632',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.940544,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445141241348378632,
#      'created_at': '2021-10-04 21:38:16 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445141241348378632,
#      'language': 'en',
#      'likes_count': 5,
#      'link': 'https://twitter.com/ALlAN0VNA/status/1445141241348378632',
#      'mentions': '[]',
#      'name': 'fiona 🦇',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:38:16',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'facebook is down tiktok is down whatsapp is down instagram is down telegram is down  twitter is down  baby are you down down down down down dooooooown doooooown even if the sky is falling down',
#      'urls': '[]',
#      'user_id': 1423294477653790725,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'allan0vna',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445142701381492741',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.9010634,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445142701381492741,
#      'created_at': '2021-10-04 21:44:04 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['down']",
#      'id': 1445142701381492741,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/kellyJuuhh/status/1445142701381492741',
#      'mentions': '[]',
#      'name': 'Julia Kelly',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:44:04',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Whatsapp is down Instagram is down Facebook is down Sorry,is finish!  #down',
#      'urls': '[]',
#      'user_id': 823548176242212867,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'kellyjuuhh',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445133881905086464',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.9010634,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445133881905086464,
#      'created_at': '2021-10-04 21:09:01 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['internetshutdown']",
#      'id': 1445133881905086464,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/SuniljenaKumar/status/1445133881905086464',
#      'mentions': '[]',
#      'name': 'Jena',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:09:01',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Twitter is down Instagram is down Facebook is down Whatsapp is down   #InternetShutDown',
#      'urls': '[]',
#      'user_id': 1283709769979551745,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'suniljenakumar',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445133920845058053',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.846822,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445133920845058053,
#      'created_at': '2021-10-04 21:09:10 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445133920845058053,
#      'language': 'en',
#      'likes_count': 7,
#      'link': 'https://twitter.com/tbbminaj/status/1445133920845058053',
#      'mentions': '[]',
#      'name': 'shabz | shalano era (2yr poshiey mootiversary)',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:09:10',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'instagram is down  twitter is down  google is down facebook is down whatsapp is down it’s going down, im yelling timber',
#      'urls': '[]',
#      'user_id': 1211775258354569216,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'tbbminaj',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445141776629653513',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.84502,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445141776629653513,
#      'created_at': '2021-10-04 21:40:23 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445141776629653513,
#      'language': 'en',
#      'likes_count': 5,
#      'link': 'https://twitter.com/ALlAN0VNA/status/1445141776629653513',
#      'mentions': '[]',
#      'name': 'fiona 🦇',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:40:23',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'facebook is down tiktok is down whatsapp is down instagram is down telegram is down  twitter is down  DOWN AT THE MEN IN MUSIC BUSINESS CONFERENCE',
#      'urls': '[]',
#      'user_id': 1423294477653790725,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'allan0vna',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137972597166082',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.834767,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137972597166082,
#      'created_at': '2021-10-04 21:25:16 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137972597166082,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/Ashley11940659/status/1445137972597166082',
#      'mentions': '[]',
#      'name': 'Ashley',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:25:16',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook is down Instagram is down WhatsApp is down',
#      'urls': '[]',
#      'user_id': 1445127005662429185,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ashley11940659',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445142686563016707',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.8340726,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445142686563016707,
#      'created_at': '2021-10-04 21:44:00 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445142686563016707,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/NoahPierau/status/1445142686563016707',
#      'mentions': '[]',
#      'name': 'NOAH',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:44:00',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook is down Whatsapp is down Instagram is down  crypto is never down 😎',
#      'urls': '[]',
#      'user_id': 2809353716,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'noahpierau',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127465400164353',
#     '_index': 'facebook_outage_tweets',
#     '_score': 6.8340726,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445126719959089153,
#      'created_at': '2021-10-04 20:43:31 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445127465400164353,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/DeathSurfing/status/1445127465400164353',
#      'mentions': '[]',
#      'name': 'Surfing',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': "[{'screen_name': 'CarBleeder', 'name': 'CarBleeder (|)', 'id': '1354540514566164480'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:43:31',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@CarBleeder Facebook is down Instagram is down Whatsapp is down Snapchat is reportedly down',
#      'urls': '[]',
#      'user_id': 1125747304877707267,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'deathsurfing',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 6.948606,
#   'total': {'relation': 'gte', 'value': 10000}},
#  'timed_out': False,
#  'took': 64}

# %% [markdown]
# ##Specialized queries(More like this query)
# > * It helps in searching the documents that are similar to given text.
# > * It uses TF-IDF scoring to retrive similar documents matching the query.
# > * The terms used are defined as,
# >> * **like**: The docuements that match this text or terms
# >> * **unllike**: The documents that does not match the terms.
# >> * If both like and unlike are used, it will behave like an or condition.

# %%
query = {
  "query": {
    "more_like_this" : {
      "fields" : ["tweet", "hashtags"],
      "like" : "#Tor #signal",
      "unlike":"#Facebook",
      "min_term_freq" : 1,
      "max_query_terms" : 12
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.102s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   if sys.path[0] == '':
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445143173551075330',
#     '_index': 'facebook_outage_tweets',
#     '_score': 22.750309,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445114730151043073,
#      'created_at': '2021-10-04 21:45:56 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143173551075330,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/AnonBlueCC/status/1445143173551075330',
#      'mentions': '[]',
#      'name': 'Richard Sanchez',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'schrep', 'name': 'Mike Schroepfer', 'id': '6182852'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:45:56',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@schrep @Facebook Use signal, use TOR',
#      'urls': '[]',
#      'user_id': 1071592301951107072,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'anonbluecc',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445140696810377231',
#     '_index': 'facebook_outage_tweets',
#     '_score': 13.217215,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445140007719669764,
#      'created_at': '2021-10-04 21:36:06 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445140696810377231,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/AlphaOlomi/status/1445140696810377231',
#      'mentions': '[]',
#      'name': 'Alpha™️',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': "[{'screen_name': 'chax255', 'name': 'Digital Native', 'id': '2182173097'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:36:06',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "@chax255 Facebook's TOR link also went down. 🤪",
#      'urls': '[]',
#      'user_id': 980363094,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'alphaolomi',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445137503367925764',
#     '_index': 'facebook_outage_tweets',
#     '_score': 12.8431425,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445137503367925764,
#      'created_at': '2021-10-04 21:23:24 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445137503367925764,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/cKure7/status/1445137503367925764',
#      'mentions': '[]',
#      'name': 'cKure',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:23:24',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "■□□□□ Facebook's TOR link also went down.   https://t.co/Sfz79P9F6H",
#      'urls': "['http://facebookwkhpilnemxj7asaniu7vnjjbiltxjqhye3mhbshg7kx5tfyd.onion']",
#      'user_id': 1247940528647348226,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ckure7',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127324677001219',
#     '_index': 'facebook_outage_tweets',
#     '_score': 12.489661,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127324677001219,
#      'created_at': '2021-10-04 20:42:58 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445127324677001219,
#      'language': 'es',
#      'likes_count': 2,
#      'link': 'https://twitter.com/antonimmo/status/1445127324677001219',
#      'mentions': '[]',
#      'name': 'Antonio Quintana',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:42:58',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'En principio se debería poder entrar a Facebook con Tor.',
#      'urls': '[]',
#      'user_id': 97371489,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'antonimmo',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143108295999489',
#     '_index': 'facebook_outage_tweets',
#     '_score': 12.155116,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143108295999489,
#      'created_at': '2021-10-04 21:45:41 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143108295999489,
#      'language': 'en',
#      'likes_count': 5,
#      'link': 'https://twitter.com/aaronsdevera/status/1445143108295999489',
#      'mentions': '[]',
#      'name': 'Aaron DeVera',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:45:41',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "oh so you all weren't using the Facebook Tor site huh",
#      'urls': '[]',
#      'user_id': 17769002,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'aaronsdevera',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445136468247293962',
#     '_index': 'facebook_outage_tweets',
#     '_score': 10.717007,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445136468247293962,
#      'created_at': '2021-10-04 21:19:18 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebook', 'whatsapp', 'instagramdown', 'signal']",
#      'id': 1445136468247293962,
#      'language': 'und',
#      'likes_count': 0,
#      'link': 'https://twitter.com/omar_karbil/status/1445136468247293962',
#      'mentions': '[]',
#      'name': 'Omar Karbil',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:19:18',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'حملوا SIGNAl #Facebook #WhatsApp #instagramdown #Signal',
#      'urls': '[]',
#      'user_id': 1408065215267151872,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'omar_karbil',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131390366912515',
#     '_index': 'facebook_outage_tweets',
#     '_score': 10.4721,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445063315990974466,
#      'created_at': '2021-10-04 20:59:07 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebook', 'facebookdown']",
#      'id': 1445131390366912515,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/TheInfoMinister/status/1445131390366912515',
#      'mentions': '[]',
#      'name': 'Muhammed al-Sahaf 🕗',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:59:07',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Facebook's TOR onion address can't route around the (DNS) problem #Facebook is having. #facebookdown   https://t.co/sYwpG9cXoj",
#      'urls': "['http://facebookwkhpilnemxj7asaniu7vnjjbiltxjqhye3mhbshg7kx5tfyd.onion/']",
#      'user_id': 153552091,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'theinfominister',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445130212220493832',
#     '_index': 'facebook_outage_tweets',
#     '_score': 10.010096,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445130212220493832,
#      'created_at': '2021-10-04 20:54:26 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445130212220493832,
#      'language': 'en',
#      'likes_count': 3,
#      'link': 'https://twitter.com/grtmsm/status/1445130212220493832',
#      'mentions': '[]',
#      'name': 'Retard ㉨',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:54:26',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'It all started with TOR browser now WhatsApp, Facebook and Instagram. End times are near send me some cash.',
#      'urls': '[]',
#      'user_id': 1223137883919470592,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'grtmsm',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127401831284739',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.61951,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127401831284739,
#      'created_at': '2021-10-04 20:43:16 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['signal', 'whatsapp', 'facebook', 'instagram']",
#      'id': 1445127401831284739,
#      'language': 'en',
#      'likes_count': 4,
#      'link': 'https://twitter.com/Darkcell17/status/1445127401831284739',
#      'mentions': "[{'screen_name': 'signalapp', 'name': 'signal', 'id': '142415193'}]",
#      'name': 'Darkcell',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/Snowden/status/1445090556388859904',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:43:16',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Signal &gt;Whatsapp+Telegram  I'm there too ....  #Signal #Whatsapp #Facebook #Instagram @signalapp",
#      'urls': '[]',
#      'user_id': 1056876667535323136,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'darkcell17',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127292548702219',
#     '_index': 'facebook_outage_tweets',
#     '_score': 9.61951,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127292548702219,
#      'created_at': '2021-10-04 20:42:50 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['apps', 'whatsapp', 'facebook', 'instagram', 'signal']",
#      'id': 1445127292548702219,
#      'language': 'es',
#      'likes_count': 0,
#      'link': 'https://twitter.com/Ady20_S/status/1445127292548702219',
#      'mentions': '[]',
#      'name': 'Adaly',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:42:50',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Alguien me cuenta qué es signal? 🤦\u200d♀️ #apps #WhatsApp #Facebook #instagram #Signal',
#      'urls': '[]',
#      'user_id': 332413279,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ady20_s',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 22.750309,
#   'total': {'relation': 'eq', 'value': 555}},
#  'timed_out': False,
#  'took': 3}

# %% [markdown]
# ##Specialized queries(Script Query)
# > * Filters documents based on a provided script. The script query is typically used in a filter context.
# > * Using scripts can result in slower search speeds.
# > * This script must return a boolean value, true or false

# %%
query = {
  "query": {
    "bool": {
      "filter": {
        "script": {
          "script": {
            "source": "doc['tweet'].value > params.size_limit",
            "lang": "painless",
            "params": {
              "size_limit": 10
            }
          }
        }
      }
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# WARNING: POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:400 request:0.100s]
# ---------------------------------------------------------------------------
# RequestError                              Traceback (most recent call last)
# <ipython-input-47-355892a10a15> in <module>()
#      16   }
#      17 }
# ---> 18 es.search(body = query,index = "facebook_outage_tweets")
#
# /usr/local/lib/python3.7/dist-packages/elasticsearch/client/utils.py in _wrapped(*args, **kwargs)
#     299                 if p in kwargs:
#     300                     params[p] = kwargs.pop(p)
# --> 301             return func(*args, params=params, headers=headers, **kwargs)
#     302
#     303         return _wrapped
#
# /usr/local/lib/python3.7/dist-packages/elasticsearch/client/__init__.py in search(self, body, index, doc_type, params, headers)
#    1768             params=params,
#    1769             headers=headers,
# -> 1770             body=body,
#    1771         )
#    1772
#
# /usr/local/lib/python3.7/dist-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     456                         raise e
#     457                 else:
# --> 458                     raise e
#     459
#     460             else:
#
# /usr/local/lib/python3.7/dist-packages/elasticsearch/transport.py in perform_request(self, method, url, headers, params, body)
#     424                     headers=headers,
#     425                     ignore=ignore,
# --> 426                     timeout=timeout,
#     427                 )
#     428
#
# /usr/local/lib/python3.7/dist-packages/elasticsearch/connection/http_urllib3.py in perform_request(self, method, url, params, body, timeout, ignore, headers)
#     285                 method, full_url, url, orig_body, duration, response.status, raw_data
#     286             )
# --> 287             self._raise_error(response.status, raw_data)
#     288
#     289         self.log_request_success(
#
# /usr/local/lib/python3.7/dist-packages/elasticsearch/connection/base.py in _raise_error(self, status_code, raw_data)
#     336
#     337         raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
# --> 338             status_code, error_message, additional_info
#     339         )
#     340
#
# RequestError: RequestError(400, 'search_phase_execution_exception', 'runtime error')

# %% [markdown]
# ##Specialized queries(Pinned Query)
# > * Promotes selected documents to rank higher than those matching a given query. This feature is typically used to guide searchers to curated documents that are promoted over and above any "organic" matches for a search. The promoted or "pinned" documents are identified using the document IDs stored in the _id field.

# %%
query = {
  "query": {
    "pinned": {
      "ids": [ "1,445,143,573,364,498,432", "1,445,143,573,347,852,288", "1,445,143,573,339,545,600" ],
      "organic": {
        "match": {
          "tweet": "facebook"
        }
      }
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   del sys.path[0]
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.558s]
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445131666754785281',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.029181112,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131666754785281,
#      'created_at': '2021-10-04 21:00:13 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445131666754785281,
#      'language': 'hu',
#      'likes_count': 0,
#      'link': 'https://twitter.com/RobertoAylmer/status/1445131666754785281',
#      'mentions': '[]',
#      'name': 'Robert  Pilon',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:00:13',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook Facebook Facebook',
#      'urls': '[]',
#      'user_id': 193063842,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'robertoaylmer',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445128615012745218',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.02898955,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445128615012745218,
#      'created_at': '2021-10-04 20:48:05 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445128615012745218,
#      'language': 'en',
#      'likes_count': 3,
#      'link': 'https://twitter.com/QuantumJJean/status/1445128615012745218',
#      'mentions': '[]',
#      'name': 'QuantumJJean',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 2,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:48:05',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Please, Ban Facebook Quit Facebook Cancel Facebook Avoid Facebook Stop Facebook Fuck Facebook',
#      'urls': '[]',
#      'user_id': 923696420305154048,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'quantumjjean',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445141832065769472',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.02836879,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 21:40:36 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445141832065769472,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/ecozentro/status/1445141832065769472',
#      'mentions': '[]',
#      'name': '/',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:40:36',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Facebook Facebook ? What is Facebook?',
#      'urls': '[]',
#      'user_id': 1384829005,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'ecozentro',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131519618686976',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.02827796,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131519618686976,
#      'created_at': '2021-10-04 20:59:38 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445131519618686976,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/_ayotomiwa/status/1445131519618686976',
#      'mentions': '[]',
#      'name': 'Tomiwa',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:59:38',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'WhatsApp: from Facebook Instagram: from Facebook Facebook: Facebook 🤦🏾',
#      'urls': '[]',
#      'user_id': 1352742101667221505,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': '_ayotomiwa',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127680479973377',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.028223742,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127680479973377,
#      'created_at': '2021-10-04 20:44:22 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445127680479973377,
#      'language': 'en',
#      'likes_count': 128,
#      'link': 'https://twitter.com/ThePokeRaf/status/1445127680479973377',
#      'mentions': '[]',
#      'name': 'Raf 🔥🐌',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 2,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 14,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:44:22',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Instagram by Facebook  WhatsApp by Facebook  Facebook by Facebook  Everything down by Facebook',
#      'urls': '[]',
#      'user_id': 4828068711,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'thepokeraf',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445132091549618176',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.027964588,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445132091549618176,
#      'created_at': '2021-10-04 21:01:54 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebook']",
#      'id': 1445132091549618176,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/DewTheZeed1/status/1445132091549618176',
#      'mentions': '[]',
#      'name': 'Dew_Kittinan',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:01:54',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook #Facebook',
#      'urls': '[]',
#      'user_id': 917000214757515266,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'dewthezeed1',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445139535654948866',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.027762413,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445139535654948866,
#      'created_at': '2021-10-04 21:31:29 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebook', 'serverdown']",
#      'id': 1445139535654948866,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/chris_kafetzis/status/1445139535654948866',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'better call chris',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:31:29',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Is Facebook the next my space? Facebook and IG Facebook &amp; IG #Facebook #serverdown @Facebook',
#      'urls': '[]',
#      'user_id': 1253783021284667394,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'chris_kafetzis',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445133308581531649',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.027658086,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131539822563334,
#      'created_at': '2021-10-04 21:06:44 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445133308581531649,
#      'language': 'en',
#      'likes_count': 5,
#      'link': 'https://twitter.com/5tuartreeves/status/1445133308581531649',
#      'mentions': '[]',
#      'name': '😶 stuart reeves 😶',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': 'https://twitter.com/MikeDoughney/status/1445089349826224131?t=p1XEqn1seLvc7TXMlDo_QQ&s=19',
#      'replies_count': 1,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:06:44',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Facebook thinks Facebook is so great that Facebook must be everywhere including every part of Facebook itself, so if Facebook breaks Facebook, Facebook can't fix Facebook because Facebook no longer permits access to Facebook   https://t.co/As3oQTeb1H",
#      'urls': "['https://twitter.com/MikeDoughney/status/1445089349826224131?t=p1XEqn1seLvc7TXMlDo_QQ&s=19']",
#      'user_id': 14495476,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': '5tuartreeves',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445141675345596425',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.027600467,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445141675345596425,
#      'created_at': '2021-10-04 21:39:59 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445141675345596425,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/copp5306/status/1445141675345596425',
#      'mentions': '[]',
#      'name': 'Martha Coppage',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:39:59',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Did Facebook put Facebook in Facebook  jail?',
#      'urls': '[]',
#      'user_id': 2413104911,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'copp5306',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445139223611420680',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.027600467,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445133116755021827,
#      'created_at': '2021-10-04 21:30:14 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445139223611420680,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/harviele/status/1445139223611420680',
#      'mentions': '[]',
#      'name': 'Harvie L Christian',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'theemisunshine', 'name': 'EmiSunshine', 'id': '704066330'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:30:14',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@theemisunshine Facebook put Facebook in Facebook Jail..',
#      'urls': '[]',
#      'user_id': 24465128,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'harviele',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 0.029181112,
#   'total': {'relation': 'gte', 'value': 10000}},
#  'timed_out': False,
#  'took': 10}

# %% [markdown]
# ## Term level Queries(Fuzzy query)
# > * Returns documents that contain terms similar to the search term, as measured by a Levenshtein edit distance.
# > * An edit distance is the number of one-character changes needed to turn one term into another. These changes can include:
# >> * Changing a character (box → fox)
# >> * Removing a character (black → lack)
# >> * Inserting a character (sic → sick)
# >> * Transposing two adjacent characters (act → cat)
# > * To find similar terms, the fuzzy query creates a set of all possible variations, or expansions, of the search term within a specified edit distance. The query then returns exact matches for each expansion.
# > * This can be useful to search even if the word is not spelled correctly.
# > * The fields used are described below,
# >> * **value**: The term to be searched.
# >> * **fuzziness**: Maximum edit distance allowed.
# >> * **max_expansions**: Maximum number of variation created default -50
# >> * **prefix_length**:Number of beginning characters left unchanged when creating expansions. Defaults to 0.
# >> * **transpositions**:Indicates whether edits include transpositions of two adjacent characters (ab → ba). Defaults to true.

# %%
query = {
  "query": {
    "fuzzy": {
      "tweet": {
        "value": "faceook",
        "fuzziness": "AUTO",
        "max_expansions": 50,
        "prefix_length": 0,
        "transpositions": True
      }
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.143s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445143936603930629',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.03839601,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143936603930629,
#      'created_at': '2021-10-04 21:48:58 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143936603930629,
#      'language': 'pt',
#      'likes_count': 1,
#      'link': 'https://twitter.com/Sakur4t3Amo/status/1445143936603930629',
#      'mentions': '[]',
#      'name': 'Mia',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:58',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'volvio facebok, VOLVIO FACEBOOK',
#      'urls': '[]',
#      'user_id': 1388184351251312646,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'sakur4t3amo',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127788219052040',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.03839601,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445127788219052040,
#      'created_at': '2021-10-04 20:44:48 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445127788219052040,
#      'language': 'pt',
#      'likes_count': 0,
#      'link': 'https://twitter.com/malekbarcelona1/status/1445127788219052040',
#      'mentions': '[]',
#      'name': 'abdelmalek',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:44:48',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facemook va remplacer Facebook',
#      'urls': '[]',
#      'user_id': 4558462996,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'malekbarcelona1',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445127985284059137',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.037432633,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 20:45:35 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445127985284059137,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/Actof_Hitler/status/1445127985284059137',
#      'mentions': '[]',
#      'name': 'Duce II',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:45:35',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Facebook Facebok is fading      Facebook is fading               Fading faaast',
#      'urls': '[]',
#      'user_id': 1399555401796915203,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'actof_hitler',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131777484406788',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.036063895,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131777484406788,
#      'created_at': '2021-10-04 21:00:39 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445131777484406788,
#      'language': 'de',
#      'likes_count': 0,
#      'link': 'https://twitter.com/Jermain19822354/status/1445131777484406788',
#      'mentions': '[]',
#      'name': 'Jermaine Moore',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:00:39',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@RheinmetallAG   10/04/2021  Mike Schroepfer  Facebook CTO Facebok  Stanford University  Mike Schroepfer  Facebook CTO Facebok  Stanford University',
#      'urls': '[]',
#      'user_id': 1224313134174867456,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'jermain19822354',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445131780605030409',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.034073055,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445131780605030409,
#      'created_at': '2021-10-04 21:00:40 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445131780605030409,
#      'language': 'en',
#      'likes_count': 14,
#      'link': 'https://twitter.com/XenokoYT/status/1445131780605030409',
#      'mentions': '[]',
#      'name': '🎃 Xenoktober 🎃 | CEO of Hot Wheels Unleashed',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 2,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:00:40',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook?  More like Faceboom 😏',
#      'urls': '[]',
#      'user_id': 3350742089,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'xenokoyt',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445141497251303431',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.033922687,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445125432311943173,
#      'created_at': '2021-10-04 21:39:17 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445141497251303431,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/AbdelkodousO/status/1445141497251303431',
#      'mentions': '[]',
#      'name': '𝘼𝙗𝙙𝙪𝙡 𝙌𝙪𝙙𝙪𝙨 👾',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': "[{'screen_name': 'Dadsaysjokes', 'name': 'Dad Jokes', 'id': '905028905026846720'}, {'screen_name': 'sabrinalamghari', 'name': 'Sabrina', 'id': '1019179749606920192'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:39:17',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Dadsaysjokes @sabrinalamghari What is better than Facebook.                    Facemok',
#      'urls': '[]',
#      'user_id': 1254934090475855880,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'abdelkodouso',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445130743286571022',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.033058573,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445130743286571022,
#      'created_at': '2021-10-04 20:56:33 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445130743286571022,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/NetanelWorthy/status/1445130743286571022',
#      'mentions': '[]',
#      'name': 'Netanel Worthy - נתנאל וורתי',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '20:56:33',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Misspelled Facebook as Faceboom and tbh…if Facebook is really gone, I’m ok with it’s successor being Faceboom.',
#      'urls': '[]',
#      'user_id': 780007954938331136,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'netanelworthy',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445136879779725315',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.033019245,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445136879779725315,
#      'created_at': '2021-10-04 21:20:56 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445136879779725315,
#      'language': 'et',
#      'likes_count': 0,
#      'link': 'https://twitter.com/francisvonwhite/status/1445136879779725315',
#      'mentions': '[]',
#      'name': 'Francesca Delbianco 📷😻🔥',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:20:56',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'A kojim userima Facebooka , Facebook tweeta?',
#      'urls': '[]',
#      'user_id': 4212396863,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'francisvonwhite',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445132078652268549',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.033019245,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 21:01:51 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445132078652268549,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/mghSPURS/status/1445132078652268549',
#      'mentions': '[]',
#      'name': 'Matty Hunter',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:01:51',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Facebook Facebooks shit pass it on',
#      'urls': '[]',
#      'user_id': 764754687383986176,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'mghspurs',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143265683156994',
#     '_index': 'facebook_outage_tweets',
#     '_score': 0.032962613,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143265683156994,
#      'created_at': '2021-10-04 21:46:18 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143265683156994,
#      'language': 'es',
#      'likes_count': 0,
#      'link': 'https://twitter.com/MaliRody/status/1445143265683156994',
#      'mentions': '[]',
#      'name': 'Mals',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:46:18',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Ya se restableció Facebok... Repito ya se restableció Facebook',
#      'urls': '[]',
#      'user_id': 265078003,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'malirody',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 0.03839601,
#   'total': {'relation': 'gte', 'value': 10000}},
#  'timed_out': False,
#  'took': 48}

# %% [markdown]
# ## Term level Queries(prefix query)
# > * Returns documents that contain a specific prefix in a provided field.

# %%
query = {
  "query": {
    "prefix": {
      "name": {
        "value": "tw"
      }
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.109s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   # Remove the CWD from sys.path while we load stuff.
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445143889472630784',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143889472630784,
#      'created_at': '2021-10-04 21:48:47 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143889472630784,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/TwoPeasNAPod2/status/1445143889472630784',
#      'mentions': "[{'screen_name': 'cryptomanran', 'name': 'ran neuner', 'id': '58487473'}, {'screen_name': 'el33th4xor', 'name': 'emin gün sirer🔺', 'id': '399412477'}]",
#      'name': 'Two Peas N A Pod',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/ext_tw_video_thumb/1445143769154793474/pu/img/EUOlIZrOPxHibCRi.jpg',
#      'time': '21:48:47',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook and IG down today … so @cryptomanran @el33th4xor  https://t.co/xyASILXppr',
#      'urls': '[]',
#      'user_id': 1293158845062184962,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'twopeasnapod2',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445143869994197005',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143869994197005,
#      'created_at': '2021-10-04 21:48:42 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143869994197005,
#      'language': 'es',
#      'likes_count': 0,
#      'link': 'https://twitter.com/twisdeldj01/status/1445143869994197005',
#      'mentions': '[]',
#      'name': 'tweets del dj',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:42',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Hoy los que esperaban mensajes de cumpleaños y felicitaciones deben estar triztes, nadie se acordó de ellos ni un mesajito por WHATSAPP y Facebook.',
#      'urls': '[]',
#      'user_id': 884502118241107968,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'twisdeldj01',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143868777844743',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143868777844743,
#      'created_at': '2021-10-04 21:48:42 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143868777844743,
#      'language': 'es',
#      'likes_count': 0,
#      'link': 'https://twitter.com/ElmesiasTwitt/status/1445143868777844743',
#      'mentions': '[]',
#      'name': 'elmesias twitt',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:42',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Tranquilos, tranquilas que los del BDV están tratando de reactivar la conexión de WhatsApp, Facebook e Instagram, pronto tendremos datos',
#      'urls': '[]',
#      'user_id': 1411632878,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'elmesiastwitt',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143990983135236',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143794526064641,
#      'created_at': '2021-10-04 21:49:11 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143990983135236,
#      'language': 'en',
#      'likes_count': 2,
#      'link': 'https://twitter.com/Smartboy1983/status/1445143990983135236',
#      'mentions': '[]',
#      'name': 'I laugh at ur tweets',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'educated_real', 'name': 'RealEducatedScholar', 'id': '1311917957937803264'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:49:11',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@educated_real There was a former employee who copied a crap load of internal reports from Facebook, before she resigned',
#      'urls': '[]',
#      'user_id': 43648549,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'smartboy1983',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143982552530944',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143982552530944,
#      'created_at': '2021-10-04 21:49:09 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143982552530944,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/OverheardISwear/status/1445143982552530944',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': '@twocanplaythatgame',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:49:09',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Hey I don't know about the rest of you but I just feel America is a much better place since @Facebook has been down. We should keep this going huh?",
#      'urls': '[]',
#      'user_id': 1392161749525217281,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'overheardiswear',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143601101492227',
#     '_ignored': ['tweet.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143601101492227,
#      'created_at': '2021-10-04 21:47:38 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143601101492227,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/zdentws/status/1445143601101492227',
#      'mentions': '[]',
#      'name': 'zden tws',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/tweet_video_thumb/FA4ucLcVkAE0Cpb.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/tweet_video_thumb/FA4ucLcVkAE0Cpb.jpg',
#      'time': '21:47:38',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Im newbie to Twitter ! Because of Facebook is down !   And because of this incident, i noticed my attachment to social medias ( Fb, Ig, Ws ), are all from same platform !   And i can't sleep well ! Look at how much socmed have my life !  https://t.co/bBirhU8ddW",
#      'urls': '[]',
#      'user_id': 1445137570870939648,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'zdentws',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445143582248038402',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143582248038402,
#      'created_at': '2021-10-04 21:47:34 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['redessociales']",
#      'id': 1445143582248038402,
#      'language': 'en',
#      'likes_count': 39,
#      'link': 'https://twitter.com/FajaTweets/status/1445143582248038402',
#      'mentions': '[]',
#      'name': 'Faja De Tweets',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4ubapXIAILlNu.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 4,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 2,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4ubapXIAILlNu.jpg',
#      'time': '21:47:34',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Ya funciona WhatsApp, Instagram y Facebook. #RedesSociales  https://t.co/iz7k8FS70G',
#      'urls': '[]',
#      'user_id': 1249405586225147905,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'fajatweets',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445143567861788676',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445061804636479493,
#      'created_at': '2021-10-04 21:47:30 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143567861788676,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/JaneenNoto/status/1445143567861788676',
#      'mentions': '[]',
#      'name': "Janeen's tweet",
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'stevenconway2', 'name': 'Steven Conway', 'id': '82259734'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:30',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@stevenconway2 @Facebook It has nothing to do with the airing of laundry last night on 60 minutes hey?!',
#      'urls': '[]',
#      'user_id': 1619397816,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'janeennoto',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143566796398596',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143566796398596,
#      'created_at': '2021-10-04 21:47:30 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143566796398596,
#      'language': 'und',
#      'likes_count': 2,
#      'link': 'https://twitter.com/hawkfromnorwalk/status/1445143566796398596',
#      'mentions': "[{'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}]",
#      'name': 'The Tweeter Formerly Known as the Hawkfromnorwalk',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/tweet_video_thumb/FA4uaZLXEA0K0sU.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/tweet_video_thumb/FA4uaZLXEA0K0sU.jpg',
#      'time': '21:47:30',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Hey @Facebook  https://t.co/GC9A345SwP',
#      'urls': '[]',
#      'user_id': 18412032,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'hawkfromnorwalk',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445143560731328520',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143560731328520,
#      'created_at': '2021-10-04 21:47:29 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143560731328520,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/venusianvillain/status/1445143560731328520',
#      'mentions': '[]',
#      'name': '🔴venusianvillain on twitch',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:29',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'instagram and facebook may be down but indeed isn’t',
#      'urls': '[]',
#      'user_id': 1333811801742426114,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'venusianvillain',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 1.0,
#   'total': {'relation': 'eq', 'value': 592}},
#  'timed_out': False,
#  'took': 10}

# %% [markdown]
# ## Term level Queries(Range query)
# > * Returns documents that contain terms within a provided range.

# %%
query = {
  "query": {
    "range": {
      "likes_count": {
        "gte": 100,
        "lte": 200,
        "boost": 2.0
      }
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.109s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   if sys.path[0] == '':
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445143926038532099',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143926038532099,
#      'created_at': '2021-10-04 21:48:56 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143926038532099,
#      'language': 'fr',
#      'likes_count': 131,
#      'link': 'https://twitter.com/SKFCB_/status/1445143926038532099',
#      'mentions': '[]',
#      'name': 'ƧK',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4uvTQWQAEzgoH.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 2,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 2,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4uvTQWQAEzgoH.jpg',
#      'time': '21:48:56',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Les techniciens chez Facebook  https://t.co/HSdeIOvtd0',
#      'urls': '[]',
#      'user_id': 1288438211254071296,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'skfcb_',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445143921294811140',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143921294811140,
#      'created_at': '2021-10-04 21:48:54 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143921294811140,
#      'language': 'da',
#      'likes_count': 110,
#      'link': 'https://twitter.com/KojoWud_/status/1445143921294811140',
#      'mentions': '[]',
#      'name': 'Kojo Wud💀',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 6,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 36,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:54',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook de3 jons nkoaa.',
#      'urls': '[]',
#      'user_id': 1385645861817004044,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'kojowud_',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143918341939200',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143918341939200,
#      'created_at': '2021-10-04 21:48:54 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': "['facebookdown', 'instagramdown', 'halloweenverse']",
#      'id': 1445143918341939200,
#      'language': 'en',
#      'likes_count': 157,
#      'link': 'https://twitter.com/DrSamLoomis78/status/1445143918341939200',
#      'mentions': '[]',
#      'name': 'Dr. Samuel Loomis',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 8,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 41,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:54',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Six apps down, Sheriff, that's what I have seen; between Twitter and Google. Facebook and Instagram up in flames! I'm telling you Michael Myers is here, in this town! #facebookdown #instagramdown #HalloweenVerse",
#      'urls': '[]',
#      'user_id': 1263187564942569472,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'drsamloomis78',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143896703569924',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143896703569924,
#      'created_at': '2021-10-04 21:48:49 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143896703569924,
#      'language': 'pt',
#      'likes_count': 102,
#      'link': 'https://twitter.com/uailucax/status/1445143896703569924',
#      'mentions': '[]',
#      'name': 'lucax',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 2,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 18,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:49',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Instagram, Facebook e whatsapp nesse momento: o cair é do homem o levantar é de Deus',
#      'urls': '[]',
#      'user_id': 3307353341,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'uailucax',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143893679411202',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143893679411202,
#      'created_at': '2021-10-04 21:48:48 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143893679411202,
#      'language': 'en',
#      'likes_count': 103,
#      'link': 'https://twitter.com/Lou_TireWorld/status/1445143893679411202',
#      'mentions': '[]',
#      'name': 'Lou Brown',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4uta6WYAEoJVa.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 5,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4uta6WYAEoJVa.jpg',
#      'time': '21:48:48',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '“All I can say is that I thought Facebook and Instagram were down.”  https://t.co/7nqAX5tiro',
#      'urls': '[]',
#      'user_id': 1938985488,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'lou_tireworld',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445143888503705601',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143888503705601,
#      'created_at': '2021-10-04 21:48:47 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143888503705601,
#      'language': 'en',
#      'likes_count': 129,
#      'link': 'https://twitter.com/sheni_coker/status/1445143888503705601',
#      'mentions': '[]',
#      'name': 'Sheni Coker',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 15,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 40,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:47',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Facebook, WhatsApp and IG are back. Oya you people should leave here abeg   It’s too crowded. Thanks for coming. ✌️',
#      'urls': '[]',
#      'user_id': 1379138809,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'sheni_coker',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143882233176072',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445142870638297089,
#      'created_at': '2021-10-04 21:48:45 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143882233176072,
#      'language': 'in',
#      'likes_count': 104,
#      'link': 'https://twitter.com/Mobistrimi/status/1445143882233176072',
#      'mentions': "[{'screen_name': 'instagram', 'name': 'instagram', 'id': '180505807'}, {'screen_name': 'facebook', 'name': 'facebook', 'id': '2425151'}, {'screen_name': 'whatsapp', 'name': 'whatsapp', 'id': '40148479'}]",
#      'name': 'rєquíєm sαlєsmαn',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': "[{'screen_name': 'maman1965', 'name': 'IG : kangmaman1965', 'id': '405822983'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 41,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/ext_tw_video_thumb/1445143806643421188/pu/img/2ZT4sLiPwu5kTVJ2.jpg',
#      'time': '21:48:45',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@maman1965 Saat Twitter lg ngejek @instagram @Facebook @WhatsApp  https://t.co/Akzzzau6Bh',
#      'urls': '[]',
#      'user_id': 486586079,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'mobistrimi',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445143875123912706',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143875123912706,
#      'created_at': '2021-10-04 21:48:43 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143875123912706,
#      'language': 'en',
#      'likes_count': 181,
#      'link': 'https://twitter.com/thedesirina/status/1445143875123912706',
#      'mentions': '[]',
#      'name': 'Desirina Boskovich',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 3,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 47,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:43',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "When Facebook, Instagram and WhatsApp went down for a full day in the 15th century, da Vinci wrote Hamlet. What's your excuse",
#      'urls': '[]',
#      'user_id': 3023063204,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'thedesirina',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143873890787328',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143873890787328,
#      'created_at': '2021-10-04 21:48:43 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143873890787328,
#      'language': 'en',
#      'likes_count': 156,
#      'link': 'https://twitter.com/esportsawards/status/1445143873890787328',
#      'mentions': '[]',
#      'name': 'Esports Awards',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 6,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 2,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:43',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "Just posted the winners of all of this year's awards on Facebook for you all to see, enjoy! 🏆🏆",
#      'urls': '[]',
#      'user_id': 4177919489,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'esportsawards',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143867804749829',
#     '_index': 'facebook_outage_tweets',
#     '_score': 2.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143867804749829,
#      'created_at': '2021-10-04 21:48:42 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143867804749829,
#      'language': 'pt',
#      'likes_count': 106,
#      'link': 'https://twitter.com/TheGeekOficial/status/1445143867804749829',
#      'mentions': '[]',
#      'name': 'The Geek | DCFanDome',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4ua2pWQAIbvtW.png', 'https://pbs.twimg.com/media/FA4ugWVXsAEKc0P.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 3,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 10,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4ua2pWQAIbvtW.png',
#      'time': '21:48:42',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'URGENTE  WhatsApp e Facebook começam a voltar a normalidade  https://t.co/QrBohnPywm',
#      'urls': '[]',
#      'user_id': 1051812038954102784,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'thegeekoficial',
#      'video': 1},
#     '_type': '_doc'}],
#   'max_score': 2.0,
#   'total': {'relation': 'eq', 'value': 2237}},
#  'timed_out': False,
#  'took': 13}

# %% [markdown]
# ## Term level Queries(Regexp query)
# > * Returns documents that contain terms matching a regular expression.
# > * **value**: This will have the regular expression that is needed.
# > * **flags**:Enables optional operators for the regular expression. For valid values and more information, see [Regular expression syntax](https://www.elastic.co/guide/en/elasticsearch/reference/current/regexp-syntax.html#regexp-optional-operators).
# > * **max_determinized_states**: Maximum number of [automaton states](https://en.wikipedia.org/wiki/Deterministic_finite_automaton) required for the query. Default is 10000.
# > * **rewrite**: Method used to rewrite the query.

# %%
query = {
  "query": {
    "regexp": {
      "tweet": {
        "value": "k.*y",
        "flags": "ALL",
        "case_insensitive": True,
        "max_determinized_states": 10000,
        "rewrite": "constant_score"
      }
    }
  }
}
es.search(body = query,index = "facebook_outage_tweets")
# Out:
# POST https://7432c5883b5246debc9e9bf514c1e552.eastus2.azure.elastic-cloud.com:9243/facebook_outage_tweets/_search [status:200 request:0.105s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: The 'body' parameter is deprecated for the 'search' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '1445143875945828365',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143875945828365,
#      'created_at': '2021-10-04 21:48:44 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143875945828365,
#      'language': 'tl',
#      'likes_count': 0,
#      'link': 'https://twitter.com/kiman13_/status/1445143875945828365',
#      'mentions': '[]',
#      'name': 'kim',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:48:44',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'yey wara klase kay outage sa facebook ngan messenger HAHA',
#      'urls': '[]',
#      'user_id': 1188809565816516610,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'kiman13_',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445144049158066189',
#     '_ignored': ['tweet.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445144049158066189,
#      'created_at': '2021-10-04 21:49:25 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445144049158066189,
#      'language': 'cs',
#      'likes_count': 3,
#      'link': 'https://twitter.com/PrasmanDunka/status/1445144049158066189',
#      'mentions': '[]',
#      'name': 'Prasman Dunka',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:49:25',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Řekni, kde ten instagram je, co se s ním mohlo stát,  řekni kde ten instáč je, kde může být.  Uživatelky během dne, okousaly si nehty do jedné Kdy se zas připojí, kdy se zas připojí.  Řekni, kde ten facebook, co se s ním mohlo stát, řekni, kde ten facebook je, kde může být..',
#      'urls': '[]',
#      'user_id': 1395035484,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'prasmandunka',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445144044347305993',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445142988397682695,
#      'created_at': '2021-10-04 21:49:24 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445144044347305993,
#      'language': 'es',
#      'likes_count': 2,
#      'link': 'https://twitter.com/judithgamer333/status/1445144044347305993',
#      'mentions': '[]',
#      'name': 'judithgamer333',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 1,
#      'reply_to': "[{'screen_name': 'Kalo_XY', 'name': '🎃HalloXY🎃', 'id': '1147936959093968896'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:49:24',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Kalo_XY Yo necesito  facebook XD que ando dd cotilla XD',
#      'urls': '[]',
#      'user_id': 1221014585022521344,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'judithgamer333',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143993084530690',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445038513842425866,
#      'created_at': '2021-10-04 21:49:12 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143993084530690,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/MichaelPetruz17/status/1445143993084530690',
#      'mentions': '[]',
#      'name': 'Michael Petruzzelli',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'GLeeRoberts1', 'name': 'G Lee Roberts', 'id': '1232479339842682880'}, {'screen_name': 'kyledcheney', 'name': 'Kyle Cheney', 'id': '23578274'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:49:12',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "@GLeeRoberts1 @kyledcheney I'm going on a limb here you're missing you're Instagram/ Facebook?",
#      'urls': '[]',
#      'user_id': 1440348402399604746,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'michaelpetruz17',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143981839421450',
#     '_ignored': ['mentions.keyword', 'reply_to.keyword', 'tweet.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445128247100989449,
#      'created_at': '2021-10-04 21:49:09 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143981839421450,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/PopoolaJoke4/status/1445143981839421450',
#      'mentions': "[{'screen_name': 'philip_richy1', 'name': '🧙\\u200d♂️ 🏌️ philip 👀', 'id': '2578208631'}, {'screen_name': 'eddywayne', 'name': 'eddy ™', 'id': '161501685'}, {'screen_name': 'said_a79', 'name': 'said ✊🏿', 'id': '1243284942236286982'}, {'screen_name': 'sanusi_lawwal', 'name': 'loyalboy🌟👌الله اكرم', 'id': '1264016340085604354'}, {'screen_name': 'popoolajoke4', 'name': 'j o k e 🌟', 'id': '1246060131659415558'}, {'screen_name': 'emmaxeboh', 'name': 'siremmax✳️', 'id': '466881012'}, {'screen_name': 'em_manuel_1', 'name': 'emmanuel🌟', 'id': '1267814996697845760'}, {'screen_name': 'iam_jerry100', 'name': 'fresh prince™ 🇬🇭', 'id': '1377739249781506058'}, {'screen_name': 'jechiboyz', 'name': 'magixx ep out!', 'id': '1263535059656679426'}, {'screen_name': 'builder_bryann', 'name': 'nosakhare bryan', 'id': '1452832794'}, {'screen_name': 'eddywayne00', 'name': 'eddy™', 'id': '1126196097293213698'}, {'screen_name': 'brightbhoy', 'name': 'brizzo 💎', 'id': '1311220392078520320'}, {'screen_name': 'chiyem4', 'name': 'mike eze 1 of agbor kingdom 👑', 'id': '1196794679485972480'}, {'screen_name': 'ezah_bae', 'name': 'bambi 🇨🇦', 'id': '1377629890950889473'}, {'screen_name': 'sagamu1stson', 'name': 'temmytourpe collins🌟🌟', 'id': '1002777636253380609'}]",
#      'name': 'J O K E 🌟',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'DOBENCHY', 'name': 'DOBENCHY', 'id': '1211738777627938816'}, {'screen_name': 'WhatsApp', 'name': 'WhatsApp', 'id': '40148479'}, {'screen_name': 'Facebook', 'name': 'Facebook', 'id': '2425151'}, {'screen_name': 'instagram', 'name': 'Instagram', 'id': '180505807'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:49:09',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@DOBENCHY @WhatsApp @Facebook @instagram @Emmaxeboh  @Philip_Richy1  @Eddywayne  @Said_A79  @Sanusi_lawwal  @PopoolaJoke4  @Emmaxeboh  @Em_Manuel_1  @iam_jerry100  @Jechiboyz  @Builder_BryanN  @eddywayne00  @Brightbhoy  @Chiyem4  @ezah_bae  @sagamu1stSON   Kindly follow and tag friends to participate, thanks',
#      'urls': '[]',
#      'user_id': 1246060131659415558,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'popoolajoke4',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143594617221123',
#     '_ignored': ['reply_to.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445142772961488897,
#      'created_at': '2021-10-04 21:47:37 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143594617221123,
#      'language': 'en',
#      'likes_count': 3,
#      'link': 'https://twitter.com/chaxb263/status/1445143594617221123',
#      'mentions': '[]',
#      'name': 'Blessing',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': '_little_wizard', 'name': 'El😇😋', 'id': '1013186983257141249'}, {'screen_name': '9inety9Wolves_', 'name': '♛JAKE De DhripGod \\uf8ff 𐎕࿐\\uf8e8', 'id': '1313789519771185153'}, {'screen_name': 'Nayombee', 'name': '𝐍𝐀𝐘𝐎𝐌𝐁𝐄 🤓', 'id': '4859177133'}, {'screen_name': 'khelvyn_boy', 'name': 'SarkCess Jnr🇬🇭🇪🇬♚', 'id': '1209968854211989504'}, {'screen_name': 'Eddie_iroro', 'name': 'iroro🇳🇬🇳🇬 🌟♚ (أحمد)', 'id': '94297212'}, {'screen_name': 'GerardOdongo', 'name': 'WhatsApp', 'id': '1118226195756142592'}, {'screen_name': 'aromatycschall', 'name': 'Nii Aroma ♚ 🥰', 'id': '502991293'}, {'screen_name': 'Issa_Esinam', 'name': '🇿🇦🌹 Issa 🅰️ Dlamini 🇿🇦', 'id': '481074080'}, {'screen_name': 'FollowKween', 'name': 'Kween❣', 'id': '1486642488'}, {'screen_name': 'abenamerlly', 'name': 'Merlinda😍 ♛', 'id': '1337007179614875648'}, {'screen_name': 'Gyiagyyimii', 'name': 'KALYJAY⁷ 👻❁', 'id': '1301909569308946432'}, {'screen_name': 'PYobiay3sinner', 'name': 'P Y', 'id': '1358183222530736133'}, {'screen_name': 'EkorsoGains', 'name': 'Ekorso❁Gains ⁷', 'id': '1314833559857827840'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 1,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:37',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': "@_little_wizard @9inety9Wolves_ @Nayombee @khelvyn_boy @Eddie_iroro @GerardOdongo @aromatycschall @Issa_Esinam @FollowKween @abenamerlly @Gyiagyyimii @PYobiay3sinner @EkorsoGains What's app Nad Facebook is back",
#      'urls': '[]',
#      'user_id': 852075658532487170,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'chaxb263',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143593002442760',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445081061151608833,
#      'created_at': '2021-10-04 21:47:36 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143593002442760,
#      'language': 'en',
#      'likes_count': 0,
#      'link': 'https://twitter.com/makeupbystefany/status/1445143593002442760',
#      'mentions': '[]',
#      'name': 'MakeupbyStefanye',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'Cule_Ben', 'name': 'Benji', 'id': '1240201903679643649'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:36',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@Cule_Ben Since Instagram and Facebook is down shop my brand Maryai Cosmetics online  https://t.co/kfy3UVbVEY',
#      'urls': "['http://www.maryaicosmetics.com']",
#      'user_id': 990180716070699008,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'makeupbystefany',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445143591161057280',
#     '_ignored': ['mentions.keyword'],
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143591161057280,
#      'created_at': '2021-10-04 21:47:36 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143591161057280,
#      'language': 'en',
#      'likes_count': 8,
#      'link': 'https://twitter.com/welovethekbfam3/status/1445143591161057280',
#      'mentions': "[{'screen_name': 'spotify', 'name': 'spotify', 'id': '17230018'}, {'screen_name': 'kanebrown', 'name': 'kane brown', 'id': '1476502188'}, {'screen_name': 'hermusicx', 'name': 'h.e.r.', 'id': '774357990711316481'}, {'screen_name': 'katelynbrown619', 'name': 'katelyn brown♡', 'id': '142894053'}, {'screen_name': 'kanebrownfamily', 'name': 'kane brown family', 'id': '1319317743561248770'}]",
#      'name': 'welovethekbfamily2021',
#      'near': '-1',
#      'photos': "['https://pbs.twimg.com/media/FA4ub12X0AUNkYZ.jpg']",
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': '[]',
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 3,
#      'source': '-1',
#      'thumbnail': 'https://pbs.twimg.com/media/FA4ub12X0AUNkYZ.jpg',
#      'time': '21:47:36',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': 'Thanks @Spotify for playing blessed and free by @kanebrown and @HERMusicx @katelynbrown619 @KaneBrownFamily while I’m waiting for Instagram and Facebook come back on!  https://t.co/BIaTly4eCh',
#      'urls': '[]',
#      'user_id': 1436220189935288322,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'welovethekbfam3',
#      'video': 1},
#     '_type': '_doc'},
#    {'_id': '1445143560446152708',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445055604670676999,
#      'created_at': '2021-10-04 21:47:28 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445143560446152708,
#      'language': 'tl',
#      'likes_count': 0,
#      'link': 'https://twitter.com/tylertje/status/1445143560446152708',
#      'mentions': '[]',
#      'name': 'Shirley Dagmil Zwiep',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'gmanews', 'name': 'GMA News', 'id': '39453212'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:47:28',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@gmanews Oo kami dito sa Europe ganun din mula pa 5 pm till now 23.47 wala pa din. Ano nangyari kay facebook.',
#      'urls': '[]',
#      'user_id': 132783432,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'tylertje',
#      'video': 0},
#     '_type': '_doc'},
#    {'_id': '1445144166426624001',
#     '_index': 'facebook_outage_tweets',
#     '_score': 1.0,
#     '_source': {'cashtags': '[]',
#      'conversation_id': 1445143600988307456,
#      'created_at': '2021-10-04 21:49:53 UTC',
#      'date': '2021-10-04',
#      'geo': '-1',
#      'hashtags': '[]',
#      'id': 1445144166426624001,
#      'language': 'en',
#      'likes_count': 1,
#      'link': 'https://twitter.com/LoreyMaryC/status/1445144166426624001',
#      'mentions': '[]',
#      'name': 'Lorey',
#      'near': '-1',
#      'photos': '[]',
#      'place': '-1',
#      'quote_url': '-1',
#      'replies_count': 0,
#      'reply_to': "[{'screen_name': 'KatlArmy', 'name': 'Katl 💜', 'id': '1413535685227819015'}]",
#      'retweet': False,
#      'retweet_date': '-1',
#      'retweet_id': '-1',
#      'retweets_count': 0,
#      'source': '-1',
#      'thumbnail': '-1',
#      'time': '21:49:53',
#      'timezone': 0,
#      'trans_dest': '-1',
#      'trans_src': '-1',
#      'translate': '-1',
#      'tweet': '@KatlArmy Rip Facebook, Instagram😅😅😅',
#      'urls': '[]',
#      'user_id': 1445139071731392526,
#      'user_rt': '-1',
#      'user_rt_id': '-1',
#      'username': 'loreymaryc',
#      'video': 0},
#     '_type': '_doc'}],
#   'max_score': 1.0,
#   'total': {'relation': 'eq', 'value': 919}},
#  'timed_out': False,
#  'took': 8}

# %% [markdown]
# # Conclusion:
# > * This Notebook tries to show how to connect with the elastic search insatnce and basic text retrival techniques using elastic search.
# > * Most of the queries used can be nested together to form a complex query as per requirement.
